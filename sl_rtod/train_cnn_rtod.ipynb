# %% [markdown]
# Resources Used
# - wget.download('https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/_downloads/da4babe668a8afb093cc7776d7e630f3/generate_tfrecord.py')
# - Setup https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html

# %% [markdown]
# # 0. LOAD virtual environment

# %%
# terminal command - isntall requirements txt
pip install -r requirements.txt

# %% [markdown]
# # 1. SETUP paths

# %%
WORKSPACE_PATH = 'Tensorflow/workspace'
SCRIPTS_PATH = 'Tensorflow/scripts'
APIMODEL_PATH = 'Tensorflow/models'
ANNOTATION_PATH = WORKSPACE_PATH+'/annotations'
IMAGE_PATH = WORKSPACE_PATH+'/images'
MODEL_PATH = WORKSPACE_PATH+'/models'
PRETRAINED_MODEL_PATH = WORKSPACE_PATH+'/pre-trained-models'
CONFIG_PATH = MODEL_PATH+'/my_ssd_mobnet/pipeline.config'
CHECKPOINT_PATH = MODEL_PATH+'/my_ssd_mobnet/'

# %% [markdown]
# # 2. CREATE label maps

# %%
# create the dictionary entries for all glosses the model shall be trained on - MAKE SURE the naming exactly matches labelimg - ad add sequential IDs
labels = [
    {'name':'hello', 'id':1}, 
    {'name':'yes', 'id':2}, 
    {'name':'no', 'id':3}, 
    {'name':'thanks', 'id':4}, 
    {'name':'i love you', 'id':5}, 
    # {'name':'montag', 'id':6},    
    # {'name':'auch', 'id':7},  
    # {'name':'mehr', 'id':8},  
    # {'name':'wolke', 'id':9},  
    # {'name':'als', 'id':10},  
    # {'name':'sonne', 'id':11},  
    # {'name':'ueberwiegend', 'id':12},  
    # {'name':'regen', 'id':13},  
    # {'name':'gewitter', 'id':14},  
    ]

with open(ANNOTATION_PATH + '/label_map.pbtxt', 'w') as f:
    for label in labels:
        f.write('item {\n') # space removed
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. CREATE tfrecord file

# %%
# downloading pretrained tf models from tf model zoo
# !cd Tensorflow && git clone https://github.com/tensorflow/models
# Out:
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
# installing object detection module (see command box below, keeping comment & command in same code created issues)

# %%
# %%bash
# cd Tensorflow/models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf1/setup.py . # updated to tf1
# python -m pip install .
# Out:
# Processing /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/Tensorflow/models/research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pillow in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (11.1.0)
# Requirement already satisfied: lxml in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (5.3.0)
# Requirement already satisfied: matplotlib in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (3.10.0)
# Requirement already satisfied: Cython in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (3.0.11)
# Requirement already satisfied: contextlib2 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.1.0)
# Requirement already satisfied: six in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.17.0)
# Requirement already satisfied: pycocotools in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (2.0.8)
# Requirement already satisfied: lvis in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.15.1)
# Requirement already satisfied: pandas in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (2.2.3)
# Requirement already satisfied: cycler>=0.10.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (1.4.8)
# Requirement already satisfied: numpy>=1.18.2 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (4.11.0.86)
# Requirement already satisfied: pyparsing>=2.4.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (4.55.8)
# Requirement already satisfied: packaging>=20.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (24.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2025.1)
# Requirement already satisfied: absl-py>=0.2.2 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from tf-slim->object_detection==0.1) (1.4.0)
# Building wheels for collected packages: object_detection
#   Building wheel for object_detection (setup.py): started
#   Building wheel for object_detection (setup.py): finished with status 'done'
#   Created wheel for object_detection: filename=object_detection-0.1-py3-none-any.whl size=1656739 sha256=deb39b2c43ad10514e6fd6b56ef02bfca8053d840cd247fee7c37f58447c86e7
#   Stored in directory: /private/var/folders/y5/l0vddhks2fj4y_tkywmly1240000gn/T/pip-ephem-wheel-cache-1fajb1zk/wheels/ed/f4/6c/bcb9019e476a83fa88035201dd62b698e5d335557fa45a84a6
# Successfully built object_detection
# Installing collected packages: object_detection
#   Attempting uninstall: object_detection
#     Found existing installation: object_detection 0.1
#     Uninstalling object_detection-0.1:
#       Successfully uninstalled object_detection-0.1
# Successfully installed object_detection-0.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
# update line of code in .venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py

"""
replace
from tensorflow.python.keras.layers.preprocessing import image_preprocessing as image_ops 
with
from tensorflow.keras.preprocessing import image as image_ops
"""


import os

# Define the path to the Python file
file_path = ".venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py"

# Define the lines to be replaced
old_line = "from tensorflow.python.keras.layers.preprocessing import image_preprocessing as image_ops"
new_line = "from tensorflow.keras.preprocessing import image as image_ops"

# Read the file and copy the old line as a comment, then add the new line
with open(file_path, 'r') as file:
    lines = file.readlines()

with open(file_path, 'w') as file:
    for line in lines:
        if old_line in line:
            file.write("# " + line)  # Comment out the old line
            file.write(new_line + '\n')  # Add the new line
        else:
            file.write(line)

print(f"Updated {file_path} with new import statement and commented out the old one.")
# Out:
# Updated .venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py with new import statement and commented out the old one.

# %%
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x{IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. COPY model config to training folder

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' # model rerun with augmented training data - folder Tensorflow/models/my_ssd_mobnet needs to be deleted otherwise training model script will throw an error

# %%
# !mkdir -p {'Tensorflow/workspace/models/' + CUSTOM_MODEL_NAME}
# !cp {PRETRAINED_MODEL_PATH + '/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config'} {MODEL_PATH + '/' + CUSTOM_MODEL_NAME}

# %% [markdown]
# # 5. UPDATE config for transfer learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
CONFIG_PATH = MODEL_PATH+'/'+CUSTOM_MODEL_NAME+'/pipeline.config'

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 4e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.01
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.997
#          scale: true
#          epsilon: 0.001
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 4e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.01
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.997
#            scale: true
#            epsilon: 0.001
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.6
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 1e-08
#        iou_threshold: 0.6
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.08
#          total_steps: 50000
#          warmup_learning_rate: 0.026666
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.9
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = 5 # UPDATE to the number of classes your model shall be trained on
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/train.record']
pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. TRAIN the model

# %%
# no. of steps set to 10000
print("""python {}/research/object_detection/model_main_tf2.py --model_dir={}/{} --pipeline_config_path={}/{}/pipeline.config --num_train_steps=10000""".format(APIMODEL_PATH, MODEL_PATH,CUSTOM_MODEL_NAME,MODEL_PATH,CUSTOM_MODEL_NAME))
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=10000

# %%
# copy paste python command to run the model 
# !python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=10000
# Out:
# /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0203 18:52:56.382397 8350614080 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I0203 18:52:56.395046 8350614080 config_util.py:552] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0203 18:52:56.395141 8350614080 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0203 18:52:56.410969 8350614080 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0203 18:52:56.414636 8350614080 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0203 18:52:56.414693 8350614080 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0203 18:52:56.414716 8350614080 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0203 18:52:56.414734 8350614080 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0203 18:52:56.418510 8350614080 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0203 18:52:56.432067 8350614080 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0203 18:52:59.552448 8350614080 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0203 18:53:00.892529 8350614080 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0203 18:53:01.546539 8350614080 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2025-02-03 18:53:02.907075: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0203 18:53:05.476090 13840035840 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0203 18:53:08.889488 13892612096 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0203 18:53:12.033622 14690840576 deprecation.py:569] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0203 18:53:12.492723 14690840576 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0203 18:53:14.745186 14763978752 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0203 18:53:16.882717 14855204864 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0203 18:53:19.033105 14959013888 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.481s
# I0203 18:53:59.674031 8350614080 model_lib_v2.py:705] Step 100 per-step time 0.481s
# INFO:tensorflow:{'Loss/classification_loss': 0.39149654,
#  'Loss/localization_loss': 0.24252471,
#  'Loss/regularization_loss': 0.15440841,
#  'Loss/total_loss': 0.7884296,
#  'learning_rate': 0.0319994}
# I0203 18:53:59.674435 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.39149654,
#  'Loss/localization_loss': 0.24252471,
#  'Loss/regularization_loss': 0.15440841,
#  'Loss/total_loss': 0.7884296,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.367s
# I0203 18:54:36.348046 8350614080 model_lib_v2.py:705] Step 200 per-step time 0.367s
# INFO:tensorflow:{'Loss/classification_loss': 0.2381862,
#  'Loss/localization_loss': 0.100844115,
#  'Loss/regularization_loss': 0.15438601,
#  'Loss/total_loss': 0.4934163,
#  'learning_rate': 0.0373328}
# I0203 18:54:36.348208 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.2381862,
#  'Loss/localization_loss': 0.100844115,
#  'Loss/regularization_loss': 0.15438601,
#  'Loss/total_loss': 0.4934163,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.383s
# I0203 18:55:14.630520 8350614080 model_lib_v2.py:705] Step 300 per-step time 0.383s
# INFO:tensorflow:{'Loss/classification_loss': 0.2436532,
#  'Loss/localization_loss': 0.1801287,
#  'Loss/regularization_loss': 0.15417212,
#  'Loss/total_loss': 0.577954,
#  'learning_rate': 0.0426662}
# I0203 18:55:14.630667 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.2436532,
#  'Loss/localization_loss': 0.1801287,
#  'Loss/regularization_loss': 0.15417212,
#  'Loss/total_loss': 0.577954,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.393s
# I0203 18:55:53.917091 8350614080 model_lib_v2.py:705] Step 400 per-step time 0.393s
# INFO:tensorflow:{'Loss/classification_loss': 0.2893007,
#  'Loss/localization_loss': 0.14112887,
#  'Loss/regularization_loss': 0.15399684,
#  'Loss/total_loss': 0.5844264,
#  'learning_rate': 0.047999598}
# I0203 18:55:53.917250 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.2893007,
#  'Loss/localization_loss': 0.14112887,
#  'Loss/regularization_loss': 0.15399684,
#  'Loss/total_loss': 0.5844264,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.387s
# I0203 18:56:32.635148 8350614080 model_lib_v2.py:705] Step 500 per-step time 0.387s
# INFO:tensorflow:{'Loss/classification_loss': 0.18398583,
#  'Loss/localization_loss': 0.12509738,
#  'Loss/regularization_loss': 0.15374452,
#  'Loss/total_loss': 0.46282774,
#  'learning_rate': 0.053333}
# I0203 18:56:32.635384 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.18398583,
#  'Loss/localization_loss': 0.12509738,
#  'Loss/regularization_loss': 0.15374452,
#  'Loss/total_loss': 0.46282774,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.404s
# I0203 18:57:13.018070 8350614080 model_lib_v2.py:705] Step 600 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.18422244,
#  'Loss/localization_loss': 0.09956362,
#  'Loss/regularization_loss': 0.15341991,
#  'Loss/total_loss': 0.43720597,
#  'learning_rate': 0.0586664}
# I0203 18:57:13.018373 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.18422244,
#  'Loss/localization_loss': 0.09956362,
#  'Loss/regularization_loss': 0.15341991,
#  'Loss/total_loss': 0.43720597,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.400s
# I0203 18:57:53.062827 8350614080 model_lib_v2.py:705] Step 700 per-step time 0.400s
# INFO:tensorflow:{'Loss/classification_loss': 0.11542008,
#  'Loss/localization_loss': 0.073834725,
#  'Loss/regularization_loss': 0.15292463,
#  'Loss/total_loss': 0.34217942,
#  'learning_rate': 0.0639998}
# I0203 18:57:53.062999 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.11542008,
#  'Loss/localization_loss': 0.073834725,
#  'Loss/regularization_loss': 0.15292463,
#  'Loss/total_loss': 0.34217942,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.374s
# I0203 18:58:30.443989 8350614080 model_lib_v2.py:705] Step 800 per-step time 0.374s
# INFO:tensorflow:{'Loss/classification_loss': 0.15874632,
#  'Loss/localization_loss': 0.060972888,
#  'Loss/regularization_loss': 0.15246853,
#  'Loss/total_loss': 0.37218773,
#  'learning_rate': 0.069333196}
# I0203 18:58:30.444156 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.15874632,
#  'Loss/localization_loss': 0.060972888,
#  'Loss/regularization_loss': 0.15246853,
#  'Loss/total_loss': 0.37218773,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.377s
# I0203 18:59:08.107254 8350614080 model_lib_v2.py:705] Step 900 per-step time 0.377s
# INFO:tensorflow:{'Loss/classification_loss': 0.12648663,
#  'Loss/localization_loss': 0.0970836,
#  'Loss/regularization_loss': 0.15199055,
#  'Loss/total_loss': 0.37556076,
#  'learning_rate': 0.074666604}
# I0203 18:59:08.107520 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.12648663,
#  'Loss/localization_loss': 0.0970836,
#  'Loss/regularization_loss': 0.15199055,
#  'Loss/total_loss': 0.37556076,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.383s
# I0203 18:59:46.396022 8350614080 model_lib_v2.py:705] Step 1000 per-step time 0.383s
# INFO:tensorflow:{'Loss/classification_loss': 0.10379774,
#  'Loss/localization_loss': 0.04198979,
#  'Loss/regularization_loss': 0.15140972,
#  'Loss/total_loss': 0.29719722,
#  'learning_rate': 0.08}
# I0203 18:59:46.396189 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.10379774,
#  'Loss/localization_loss': 0.04198979,
#  'Loss/regularization_loss': 0.15140972,
#  'Loss/total_loss': 0.29719722,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.364s
# I0203 19:00:22.805793 8350614080 model_lib_v2.py:705] Step 1100 per-step time 0.364s
# INFO:tensorflow:{'Loss/classification_loss': 0.098275796,
#  'Loss/localization_loss': 0.048806928,
#  'Loss/regularization_loss': 0.15088204,
#  'Loss/total_loss': 0.29796475,
#  'learning_rate': 0.07999918}
# I0203 19:00:22.806019 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.098275796,
#  'Loss/localization_loss': 0.048806928,
#  'Loss/regularization_loss': 0.15088204,
#  'Loss/total_loss': 0.29796475,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.381s
# I0203 19:01:00.895781 8350614080 model_lib_v2.py:705] Step 1200 per-step time 0.381s
# INFO:tensorflow:{'Loss/classification_loss': 0.091513716,
#  'Loss/localization_loss': 0.04702283,
#  'Loss/regularization_loss': 0.15033688,
#  'Loss/total_loss': 0.28887343,
#  'learning_rate': 0.079996705}
# I0203 19:01:00.896447 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.091513716,
#  'Loss/localization_loss': 0.04702283,
#  'Loss/regularization_loss': 0.15033688,
#  'Loss/total_loss': 0.28887343,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.405s
# I0203 19:01:41.427756 8350614080 model_lib_v2.py:705] Step 1300 per-step time 0.405s
# INFO:tensorflow:{'Loss/classification_loss': 0.17815532,
#  'Loss/localization_loss': 0.048086368,
#  'Loss/regularization_loss': 0.14966255,
#  'Loss/total_loss': 0.37590423,
#  'learning_rate': 0.0799926}
# I0203 19:01:41.427962 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.17815532,
#  'Loss/localization_loss': 0.048086368,
#  'Loss/regularization_loss': 0.14966255,
#  'Loss/total_loss': 0.37590423,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.385s
# I0203 19:02:19.969162 8350614080 model_lib_v2.py:705] Step 1400 per-step time 0.385s
# INFO:tensorflow:{'Loss/classification_loss': 0.051930524,
#  'Loss/localization_loss': 0.031207414,
#  'Loss/regularization_loss': 0.14895935,
#  'Loss/total_loss': 0.2320973,
#  'learning_rate': 0.07998685}
# I0203 19:02:19.969798 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.051930524,
#  'Loss/localization_loss': 0.031207414,
#  'Loss/regularization_loss': 0.14895935,
#  'Loss/total_loss': 0.2320973,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.425s
# I0203 19:03:02.440380 8350614080 model_lib_v2.py:705] Step 1500 per-step time 0.425s
# INFO:tensorflow:{'Loss/classification_loss': 0.116831765,
#  'Loss/localization_loss': 0.041223682,
#  'Loss/regularization_loss': 0.14852306,
#  'Loss/total_loss': 0.30657852,
#  'learning_rate': 0.07997945}
# I0203 19:03:02.441014 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.116831765,
#  'Loss/localization_loss': 0.041223682,
#  'Loss/regularization_loss': 0.14852306,
#  'Loss/total_loss': 0.30657852,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.480s
# I0203 19:03:50.412765 8350614080 model_lib_v2.py:705] Step 1600 per-step time 0.480s
# INFO:tensorflow:{'Loss/classification_loss': 0.07147108,
#  'Loss/localization_loss': 0.037625965,
#  'Loss/regularization_loss': 0.14809617,
#  'Loss/total_loss': 0.2571932,
#  'learning_rate': 0.079970405}
# I0203 19:03:50.413385 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.07147108,
#  'Loss/localization_loss': 0.037625965,
#  'Loss/regularization_loss': 0.14809617,
#  'Loss/total_loss': 0.2571932,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.387s
# I0203 19:04:29.133989 8350614080 model_lib_v2.py:705] Step 1700 per-step time 0.387s
# INFO:tensorflow:{'Loss/classification_loss': 0.10661066,
#  'Loss/localization_loss': 0.02021992,
#  'Loss/regularization_loss': 0.14736086,
#  'Loss/total_loss': 0.27419144,
#  'learning_rate': 0.07995972}
# I0203 19:04:29.134170 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.10661066,
#  'Loss/localization_loss': 0.02021992,
#  'Loss/regularization_loss': 0.14736086,
#  'Loss/total_loss': 0.27419144,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.394s
# I0203 19:05:08.550097 8350614080 model_lib_v2.py:705] Step 1800 per-step time 0.394s
# INFO:tensorflow:{'Loss/classification_loss': 0.10230688,
#  'Loss/localization_loss': 0.025323499,
#  'Loss/regularization_loss': 0.14663969,
#  'Loss/total_loss': 0.27427006,
#  'learning_rate': 0.0799474}
# I0203 19:05:08.550274 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.10230688,
#  'Loss/localization_loss': 0.025323499,
#  'Loss/regularization_loss': 0.14663969,
#  'Loss/total_loss': 0.27427006,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.414s
# I0203 19:05:49.979258 8350614080 model_lib_v2.py:705] Step 1900 per-step time 0.414s
# INFO:tensorflow:{'Loss/classification_loss': 0.08507644,
#  'Loss/localization_loss': 0.041400567,
#  'Loss/regularization_loss': 0.14590476,
#  'Loss/total_loss': 0.27238178,
#  'learning_rate': 0.07993342}
# I0203 19:05:49.979923 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.08507644,
#  'Loss/localization_loss': 0.041400567,
#  'Loss/regularization_loss': 0.14590476,
#  'Loss/total_loss': 0.27238178,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.387s
# I0203 19:06:28.712469 8350614080 model_lib_v2.py:705] Step 2000 per-step time 0.387s
# INFO:tensorflow:{'Loss/classification_loss': 0.056941405,
#  'Loss/localization_loss': 0.028613312,
#  'Loss/regularization_loss': 0.14515606,
#  'Loss/total_loss': 0.23071077,
#  'learning_rate': 0.07991781}
# I0203 19:06:28.712714 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.056941405,
#  'Loss/localization_loss': 0.028613312,
#  'Loss/regularization_loss': 0.14515606,
#  'Loss/total_loss': 0.23071077,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 9.307s
# I0203 19:21:59.375767 8350614080 model_lib_v2.py:705] Step 2100 per-step time 9.307s
# INFO:tensorflow:{'Loss/classification_loss': 0.106002085,
#  'Loss/localization_loss': 0.025039347,
#  'Loss/regularization_loss': 0.14440964,
#  'Loss/total_loss': 0.27545106,
#  'learning_rate': 0.07990056}
# I0203 19:21:59.375908 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.106002085,
#  'Loss/localization_loss': 0.025039347,
#  'Loss/regularization_loss': 0.14440964,
#  'Loss/total_loss': 0.27545106,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 9.314s
# I0203 19:37:30.814459 8350614080 model_lib_v2.py:705] Step 2200 per-step time 9.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.119828425,
#  'Loss/localization_loss': 0.029182635,
#  'Loss/regularization_loss': 0.143737,
#  'Loss/total_loss': 0.29274806,
#  'learning_rate': 0.07988167}
# I0203 19:37:30.814950 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.119828425,
#  'Loss/localization_loss': 0.029182635,
#  'Loss/regularization_loss': 0.143737,
#  'Loss/total_loss': 0.29274806,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.310s
# I0203 19:38:01.815391 8350614080 model_lib_v2.py:705] Step 2300 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.1128569,
#  'Loss/localization_loss': 0.0433599,
#  'Loss/regularization_loss': 0.14365873,
#  'Loss/total_loss': 0.29987553,
#  'learning_rate': 0.07986114}
# I0203 19:38:01.815510 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.1128569,
#  'Loss/localization_loss': 0.0433599,
#  'Loss/regularization_loss': 0.14365873,
#  'Loss/total_loss': 0.29987553,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.331s
# I0203 19:38:34.884654 8350614080 model_lib_v2.py:705] Step 2400 per-step time 0.331s
# INFO:tensorflow:{'Loss/classification_loss': 0.055686098,
#  'Loss/localization_loss': 0.017186834,
#  'Loss/regularization_loss': 0.14293757,
#  'Loss/total_loss': 0.21581051,
#  'learning_rate': 0.07983897}
# I0203 19:38:34.885218 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.055686098,
#  'Loss/localization_loss': 0.017186834,
#  'Loss/regularization_loss': 0.14293757,
#  'Loss/total_loss': 0.21581051,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.326s
# I0203 19:39:07.459204 8350614080 model_lib_v2.py:705] Step 2500 per-step time 0.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.05603794,
#  'Loss/localization_loss': 0.027057808,
#  'Loss/regularization_loss': 0.14219706,
#  'Loss/total_loss': 0.2252928,
#  'learning_rate': 0.079815164}
# I0203 19:39:07.459355 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.05603794,
#  'Loss/localization_loss': 0.027057808,
#  'Loss/regularization_loss': 0.14219706,
#  'Loss/total_loss': 0.2252928,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.331s
# I0203 19:39:40.585104 8350614080 model_lib_v2.py:705] Step 2600 per-step time 0.331s
# INFO:tensorflow:{'Loss/classification_loss': 0.102854244,
#  'Loss/localization_loss': 0.02691648,
#  'Loss/regularization_loss': 0.14147304,
#  'Loss/total_loss': 0.27124375,
#  'learning_rate': 0.07978972}
# I0203 19:39:40.585251 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.102854244,
#  'Loss/localization_loss': 0.02691648,
#  'Loss/regularization_loss': 0.14147304,
#  'Loss/total_loss': 0.27124375,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.339s
# I0203 19:40:14.479421 8350614080 model_lib_v2.py:705] Step 2700 per-step time 0.339s
# INFO:tensorflow:{'Loss/classification_loss': 0.06669381,
#  'Loss/localization_loss': 0.018678904,
#  'Loss/regularization_loss': 0.14072733,
#  'Loss/total_loss': 0.22610004,
#  'learning_rate': 0.07976264}
# I0203 19:40:14.479573 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.06669381,
#  'Loss/localization_loss': 0.018678904,
#  'Loss/regularization_loss': 0.14072733,
#  'Loss/total_loss': 0.22610004,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.338s
# I0203 19:40:48.279568 8350614080 model_lib_v2.py:705] Step 2800 per-step time 0.338s
# INFO:tensorflow:{'Loss/classification_loss': 0.069948345,
#  'Loss/localization_loss': 0.014771408,
#  'Loss/regularization_loss': 0.1399518,
#  'Loss/total_loss': 0.22467154,
#  'learning_rate': 0.07973392}
# I0203 19:40:48.279722 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.069948345,
#  'Loss/localization_loss': 0.014771408,
#  'Loss/regularization_loss': 0.1399518,
#  'Loss/total_loss': 0.22467154,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.337s
# I0203 19:41:22.004613 8350614080 model_lib_v2.py:705] Step 2900 per-step time 0.337s
# INFO:tensorflow:{'Loss/classification_loss': 0.05593912,
#  'Loss/localization_loss': 0.018150909,
#  'Loss/regularization_loss': 0.1392424,
#  'Loss/total_loss': 0.21333243,
#  'learning_rate': 0.07970358}
# I0203 19:41:22.004770 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.05593912,
#  'Loss/localization_loss': 0.018150909,
#  'Loss/regularization_loss': 0.1392424,
#  'Loss/total_loss': 0.21333243,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.338s
# I0203 19:41:55.757673 8350614080 model_lib_v2.py:705] Step 3000 per-step time 0.338s
# INFO:tensorflow:{'Loss/classification_loss': 0.054150652,
#  'Loss/localization_loss': 0.02348063,
#  'Loss/regularization_loss': 0.13848956,
#  'Loss/total_loss': 0.21612084,
#  'learning_rate': 0.0796716}
# I0203 19:41:55.757829 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.054150652,
#  'Loss/localization_loss': 0.02348063,
#  'Loss/regularization_loss': 0.13848956,
#  'Loss/total_loss': 0.21612084,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.345s
# I0203 19:42:30.241084 8350614080 model_lib_v2.py:705] Step 3100 per-step time 0.345s
# INFO:tensorflow:{'Loss/classification_loss': 0.049230773,
#  'Loss/localization_loss': 0.021091308,
#  'Loss/regularization_loss': 0.13772376,
#  'Loss/total_loss': 0.20804584,
#  'learning_rate': 0.07963799}
# I0203 19:42:30.241301 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.049230773,
#  'Loss/localization_loss': 0.021091308,
#  'Loss/regularization_loss': 0.13772376,
#  'Loss/total_loss': 0.20804584,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.342s
# I0203 19:43:04.421237 8350614080 model_lib_v2.py:705] Step 3200 per-step time 0.342s
# INFO:tensorflow:{'Loss/classification_loss': 0.03245515,
#  'Loss/localization_loss': 0.028762491,
#  'Loss/regularization_loss': 0.13698293,
#  'Loss/total_loss': 0.19820057,
#  'learning_rate': 0.07960275}
# I0203 19:43:04.421402 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.03245515,
#  'Loss/localization_loss': 0.028762491,
#  'Loss/regularization_loss': 0.13698293,
#  'Loss/total_loss': 0.19820057,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.343s
# I0203 19:43:38.735522 8350614080 model_lib_v2.py:705] Step 3300 per-step time 0.343s
# INFO:tensorflow:{'Loss/classification_loss': 0.24645075,
#  'Loss/localization_loss': 0.081993766,
#  'Loss/regularization_loss': 0.1385503,
#  'Loss/total_loss': 0.46699482,
#  'learning_rate': 0.07956588}
# I0203 19:43:38.735666 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.24645075,
#  'Loss/localization_loss': 0.081993766,
#  'Loss/regularization_loss': 0.1385503,
#  'Loss/total_loss': 0.46699482,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.355s
# I0203 19:44:14.238378 8350614080 model_lib_v2.py:705] Step 3400 per-step time 0.355s
# INFO:tensorflow:{'Loss/classification_loss': 0.09688128,
#  'Loss/localization_loss': 0.015524131,
#  'Loss/regularization_loss': 0.13906656,
#  'Loss/total_loss': 0.25147197,
#  'learning_rate': 0.079527386}
# I0203 19:44:14.238543 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.09688128,
#  'Loss/localization_loss': 0.015524131,
#  'Loss/regularization_loss': 0.13906656,
#  'Loss/total_loss': 0.25147197,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.728s
# I0203 19:45:27.064602 8350614080 model_lib_v2.py:705] Step 3500 per-step time 0.728s
# INFO:tensorflow:{'Loss/classification_loss': 0.056588683,
#  'Loss/localization_loss': 0.02663266,
#  'Loss/regularization_loss': 0.13834493,
#  'Loss/total_loss': 0.22156627,
#  'learning_rate': 0.07948727}
# I0203 19:45:27.064779 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.056588683,
#  'Loss/localization_loss': 0.02663266,
#  'Loss/regularization_loss': 0.13834493,
#  'Loss/total_loss': 0.22156627,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.378s
# I0203 19:46:04.880558 8350614080 model_lib_v2.py:705] Step 3600 per-step time 0.378s
# INFO:tensorflow:{'Loss/classification_loss': 0.056223575,
#  'Loss/localization_loss': 0.019208284,
#  'Loss/regularization_loss': 0.13762654,
#  'Loss/total_loss': 0.21305841,
#  'learning_rate': 0.079445526}
# I0203 19:46:04.880741 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.056223575,
#  'Loss/localization_loss': 0.019208284,
#  'Loss/regularization_loss': 0.13762654,
#  'Loss/total_loss': 0.21305841,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.395s
# I0203 19:46:44.416321 8350614080 model_lib_v2.py:705] Step 3700 per-step time 0.395s
# INFO:tensorflow:{'Loss/classification_loss': 0.057627168,
#  'Loss/localization_loss': 0.018845893,
#  'Loss/regularization_loss': 0.13690853,
#  'Loss/total_loss': 0.21338159,
#  'learning_rate': 0.07940216}
# I0203 19:46:44.416526 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.057627168,
#  'Loss/localization_loss': 0.018845893,
#  'Loss/regularization_loss': 0.13690853,
#  'Loss/total_loss': 0.21338159,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.412s
# I0203 19:47:25.596631 8350614080 model_lib_v2.py:705] Step 3800 per-step time 0.412s
# INFO:tensorflow:{'Loss/classification_loss': 0.061604686,
#  'Loss/localization_loss': 0.017026853,
#  'Loss/regularization_loss': 0.13668081,
#  'Loss/total_loss': 0.21531236,
#  'learning_rate': 0.079357184}
# I0203 19:47:25.596848 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.061604686,
#  'Loss/localization_loss': 0.017026853,
#  'Loss/regularization_loss': 0.13668081,
#  'Loss/total_loss': 0.21531236,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.429s
# I0203 19:48:08.458004 8350614080 model_lib_v2.py:705] Step 3900 per-step time 0.429s
# INFO:tensorflow:{'Loss/classification_loss': 0.04329682,
#  'Loss/localization_loss': 0.022588985,
#  'Loss/regularization_loss': 0.13598083,
#  'Loss/total_loss': 0.20186663,
#  'learning_rate': 0.07931058}
# I0203 19:48:08.458227 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.04329682,
#  'Loss/localization_loss': 0.022588985,
#  'Loss/regularization_loss': 0.13598083,
#  'Loss/total_loss': 0.20186663,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.439s
# I0203 19:48:52.355430 8350614080 model_lib_v2.py:705] Step 4000 per-step time 0.439s
# INFO:tensorflow:{'Loss/classification_loss': 0.08407394,
#  'Loss/localization_loss': 0.0345986,
#  'Loss/regularization_loss': 0.13523258,
#  'Loss/total_loss': 0.25390512,
#  'learning_rate': 0.07926236}
# I0203 19:48:52.355824 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.08407394,
#  'Loss/localization_loss': 0.0345986,
#  'Loss/regularization_loss': 0.13523258,
#  'Loss/total_loss': 0.25390512,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.448s
# I0203 19:49:37.121062 8350614080 model_lib_v2.py:705] Step 4100 per-step time 0.448s
# INFO:tensorflow:{'Loss/classification_loss': 0.046510532,
#  'Loss/localization_loss': 0.016019227,
#  'Loss/regularization_loss': 0.13450213,
#  'Loss/total_loss': 0.19703189,
#  'learning_rate': 0.07921253}
# I0203 19:49:37.121356 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.046510532,
#  'Loss/localization_loss': 0.016019227,
#  'Loss/regularization_loss': 0.13450213,
#  'Loss/total_loss': 0.19703189,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.446s
# I0203 19:50:21.762093 8350614080 model_lib_v2.py:705] Step 4200 per-step time 0.446s
# INFO:tensorflow:{'Loss/classification_loss': 0.07385297,
#  'Loss/localization_loss': 0.034810703,
#  'Loss/regularization_loss': 0.13424844,
#  'Loss/total_loss': 0.24291211,
#  'learning_rate': 0.07916109}
# I0203 19:50:21.762320 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.07385297,
#  'Loss/localization_loss': 0.034810703,
#  'Loss/regularization_loss': 0.13424844,
#  'Loss/total_loss': 0.24291211,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.458s
# I0203 19:51:07.560626 8350614080 model_lib_v2.py:705] Step 4300 per-step time 0.458s
# INFO:tensorflow:{'Loss/classification_loss': 0.07292741,
#  'Loss/localization_loss': 0.024894783,
#  'Loss/regularization_loss': 0.13354783,
#  'Loss/total_loss': 0.23137003,
#  'learning_rate': 0.07910804}
# I0203 19:51:07.560901 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.07292741,
#  'Loss/localization_loss': 0.024894783,
#  'Loss/regularization_loss': 0.13354783,
#  'Loss/total_loss': 0.23137003,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.471s
# I0203 19:51:54.669455 8350614080 model_lib_v2.py:705] Step 4400 per-step time 0.471s
# INFO:tensorflow:{'Loss/classification_loss': 0.048220374,
#  'Loss/localization_loss': 0.012030355,
#  'Loss/regularization_loss': 0.13282038,
#  'Loss/total_loss': 0.1930711,
#  'learning_rate': 0.07905338}
# I0203 19:51:54.669736 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.048220374,
#  'Loss/localization_loss': 0.012030355,
#  'Loss/regularization_loss': 0.13282038,
#  'Loss/total_loss': 0.1930711,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.475s
# I0203 19:52:42.118100 8350614080 model_lib_v2.py:705] Step 4500 per-step time 0.475s
# INFO:tensorflow:{'Loss/classification_loss': 0.05599931,
#  'Loss/localization_loss': 0.010049015,
#  'Loss/regularization_loss': 0.13208865,
#  'Loss/total_loss': 0.19813697,
#  'learning_rate': 0.07899711}
# I0203 19:52:42.118330 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.05599931,
#  'Loss/localization_loss': 0.010049015,
#  'Loss/regularization_loss': 0.13208865,
#  'Loss/total_loss': 0.19813697,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 9.594s
# I0203 20:08:41.520770 8350614080 model_lib_v2.py:705] Step 4600 per-step time 9.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.025640057,
#  'Loss/localization_loss': 0.019665388,
#  'Loss/regularization_loss': 0.13134539,
#  'Loss/total_loss': 0.17665084,
#  'learning_rate': 0.078939244}
# I0203 20:08:41.520894 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.025640057,
#  'Loss/localization_loss': 0.019665388,
#  'Loss/regularization_loss': 0.13134539,
#  'Loss/total_loss': 0.17665084,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 9.551s
# I0203 20:24:36.655461 8350614080 model_lib_v2.py:705] Step 4700 per-step time 9.551s
# INFO:tensorflow:{'Loss/classification_loss': 0.04880168,
#  'Loss/localization_loss': 0.01730024,
#  'Loss/regularization_loss': 0.13062996,
#  'Loss/total_loss': 0.19673188,
#  'learning_rate': 0.07887978}
# I0203 20:24:36.655675 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.04880168,
#  'Loss/localization_loss': 0.01730024,
#  'Loss/regularization_loss': 0.13062996,
#  'Loss/total_loss': 0.19673188,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.299s
# I0203 20:25:06.507291 8350614080 model_lib_v2.py:705] Step 4800 per-step time 0.299s
# INFO:tensorflow:{'Loss/classification_loss': 0.052606557,
#  'Loss/localization_loss': 0.016000275,
#  'Loss/regularization_loss': 0.12991942,
#  'Loss/total_loss': 0.19852625,
#  'learning_rate': 0.07881871}
# I0203 20:25:06.507418 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.052606557,
#  'Loss/localization_loss': 0.016000275,
#  'Loss/regularization_loss': 0.12991942,
#  'Loss/total_loss': 0.19852625,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 9.551s
# I0203 20:41:01.625216 8350614080 model_lib_v2.py:705] Step 4900 per-step time 9.551s
# INFO:tensorflow:{'Loss/classification_loss': 0.039089758,
#  'Loss/localization_loss': 0.013189156,
#  'Loss/regularization_loss': 0.12921633,
#  'Loss/total_loss': 0.18149523,
#  'learning_rate': 0.07875605}
# I0203 20:41:01.625343 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.039089758,
#  'Loss/localization_loss': 0.013189156,
#  'Loss/regularization_loss': 0.12921633,
#  'Loss/total_loss': 0.18149523,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.299s
# I0203 20:41:31.566781 8350614080 model_lib_v2.py:705] Step 5000 per-step time 0.299s
# INFO:tensorflow:{'Loss/classification_loss': 0.059000902,
#  'Loss/localization_loss': 0.017459523,
#  'Loss/regularization_loss': 0.12849696,
#  'Loss/total_loss': 0.2049574,
#  'learning_rate': 0.078691795}
# I0203 20:41:31.566901 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.059000902,
#  'Loss/localization_loss': 0.017459523,
#  'Loss/regularization_loss': 0.12849696,
#  'Loss/total_loss': 0.2049574,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.310s
# I0203 20:42:02.578870 8350614080 model_lib_v2.py:705] Step 5100 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.028479254,
#  'Loss/localization_loss': 0.017847907,
#  'Loss/regularization_loss': 0.12781344,
#  'Loss/total_loss': 0.1741406,
#  'learning_rate': 0.07862595}
# I0203 20:42:02.579347 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.028479254,
#  'Loss/localization_loss': 0.017847907,
#  'Loss/regularization_loss': 0.12781344,
#  'Loss/total_loss': 0.1741406,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 9.577s
# I0203 20:58:00.316332 8350614080 model_lib_v2.py:705] Step 5200 per-step time 9.577s
# INFO:tensorflow:{'Loss/classification_loss': 0.042789415,
#  'Loss/localization_loss': 0.022672476,
#  'Loss/regularization_loss': 0.12711112,
#  'Loss/total_loss': 0.19257301,
#  'learning_rate': 0.07855851}
# I0203 20:58:00.316552 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.042789415,
#  'Loss/localization_loss': 0.022672476,
#  'Loss/regularization_loss': 0.12711112,
#  'Loss/total_loss': 0.19257301,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.304s
# I0203 20:58:30.749728 8350614080 model_lib_v2.py:705] Step 5300 per-step time 0.304s
# INFO:tensorflow:{'Loss/classification_loss': 0.07516614,
#  'Loss/localization_loss': 0.015054072,
#  'Loss/regularization_loss': 0.1264273,
#  'Loss/total_loss': 0.2166475,
#  'learning_rate': 0.07848949}
# I0203 20:58:30.749855 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.07516614,
#  'Loss/localization_loss': 0.015054072,
#  'Loss/regularization_loss': 0.1264273,
#  'Loss/total_loss': 0.2166475,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.307s
# I0203 20:59:01.479355 8350614080 model_lib_v2.py:705] Step 5400 per-step time 0.307s
# INFO:tensorflow:{'Loss/classification_loss': 0.049368955,
#  'Loss/localization_loss': 0.014262915,
#  'Loss/regularization_loss': 0.12576087,
#  'Loss/total_loss': 0.18939275,
#  'learning_rate': 0.078418896}
# I0203 20:59:01.479587 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.049368955,
#  'Loss/localization_loss': 0.014262915,
#  'Loss/regularization_loss': 0.12576087,
#  'Loss/total_loss': 0.18939275,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.319s
# I0203 20:59:33.414869 8350614080 model_lib_v2.py:705] Step 5500 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.0212474,
#  'Loss/localization_loss': 0.017357066,
#  'Loss/regularization_loss': 0.12506394,
#  'Loss/total_loss': 0.16366841,
#  'learning_rate': 0.078346714}
# I0203 20:59:33.415102 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.0212474,
#  'Loss/localization_loss': 0.017357066,
#  'Loss/regularization_loss': 0.12506394,
#  'Loss/total_loss': 0.16366841,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 4.210s
# I0203 21:06:34.388230 8350614080 model_lib_v2.py:705] Step 5600 per-step time 4.210s
# INFO:tensorflow:{'Loss/classification_loss': 0.0590143,
#  'Loss/localization_loss': 0.013940289,
#  'Loss/regularization_loss': 0.12440295,
#  'Loss/total_loss': 0.19735754,
#  'learning_rate': 0.07827295}
# I0203 21:06:34.388370 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.0590143,
#  'Loss/localization_loss': 0.013940289,
#  'Loss/regularization_loss': 0.12440295,
#  'Loss/total_loss': 0.19735754,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.302s
# I0203 21:07:04.626970 8350614080 model_lib_v2.py:705] Step 5700 per-step time 0.302s
# INFO:tensorflow:{'Loss/classification_loss': 0.050850566,
#  'Loss/localization_loss': 0.022148238,
#  'Loss/regularization_loss': 0.12375452,
#  'Loss/total_loss': 0.19675334,
#  'learning_rate': 0.07819763}
# I0203 21:07:04.627110 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.050850566,
#  'Loss/localization_loss': 0.022148238,
#  'Loss/regularization_loss': 0.12375452,
#  'Loss/total_loss': 0.19675334,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 6.368s
# I0203 21:17:41.406514 8350614080 model_lib_v2.py:705] Step 5800 per-step time 6.368s
# INFO:tensorflow:{'Loss/classification_loss': 0.060774602,
#  'Loss/localization_loss': 0.014071168,
#  'Loss/regularization_loss': 0.123083815,
#  'Loss/total_loss': 0.19792959,
#  'learning_rate': 0.07812072}
# I0203 21:17:41.406641 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.060774602,
#  'Loss/localization_loss': 0.014071168,
#  'Loss/regularization_loss': 0.123083815,
#  'Loss/total_loss': 0.19792959,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 9.600s
# I0203 21:33:41.409280 8350614080 model_lib_v2.py:705] Step 5900 per-step time 9.600s
# INFO:tensorflow:{'Loss/classification_loss': 0.064703755,
#  'Loss/localization_loss': 0.012235545,
#  'Loss/regularization_loss': 0.12244398,
#  'Loss/total_loss': 0.19938329,
#  'learning_rate': 0.078042254}
# I0203 21:33:41.409408 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.064703755,
#  'Loss/localization_loss': 0.012235545,
#  'Loss/regularization_loss': 0.12244398,
#  'Loss/total_loss': 0.19938329,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.300s
# I0203 21:34:11.402965 8350614080 model_lib_v2.py:705] Step 6000 per-step time 0.300s
# INFO:tensorflow:{'Loss/classification_loss': 0.038096268,
#  'Loss/localization_loss': 0.016084846,
#  'Loss/regularization_loss': 0.121782884,
#  'Loss/total_loss': 0.175964,
#  'learning_rate': 0.07796223}
# I0203 21:34:11.403100 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.038096268,
#  'Loss/localization_loss': 0.016084846,
#  'Loss/regularization_loss': 0.121782884,
#  'Loss/total_loss': 0.175964,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 9.482s
# I0203 21:49:59.573412 8350614080 model_lib_v2.py:705] Step 6100 per-step time 9.482s
# INFO:tensorflow:{'Loss/classification_loss': 0.07082358,
#  'Loss/localization_loss': 0.014472759,
#  'Loss/regularization_loss': 0.121123314,
#  'Loss/total_loss': 0.20641965,
#  'learning_rate': 0.077880636}
# I0203 21:49:59.573920 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.07082358,
#  'Loss/localization_loss': 0.014472759,
#  'Loss/regularization_loss': 0.121123314,
#  'Loss/total_loss': 0.20641965,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.309s
# I0203 21:50:30.491052 8350614080 model_lib_v2.py:705] Step 6200 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.046484098,
#  'Loss/localization_loss': 0.013153387,
#  'Loss/regularization_loss': 0.12047369,
#  'Loss/total_loss': 0.18011118,
#  'learning_rate': 0.07779749}
# I0203 21:50:30.491181 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.046484098,
#  'Loss/localization_loss': 0.013153387,
#  'Loss/regularization_loss': 0.12047369,
#  'Loss/total_loss': 0.18011118,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 3.537s
# I0203 21:56:24.234112 8350614080 model_lib_v2.py:705] Step 6300 per-step time 3.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.037703477,
#  'Loss/localization_loss': 0.016716704,
#  'Loss/regularization_loss': 0.119833656,
#  'Loss/total_loss': 0.17425385,
#  'learning_rate': 0.07771279}
# I0203 21:56:24.234620 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.037703477,
#  'Loss/localization_loss': 0.016716704,
#  'Loss/regularization_loss': 0.119833656,
#  'Loss/total_loss': 0.17425385,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.314s
# I0203 21:56:55.633701 8350614080 model_lib_v2.py:705] Step 6400 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.04896483,
#  'Loss/localization_loss': 0.01565394,
#  'Loss/regularization_loss': 0.1191955,
#  'Loss/total_loss': 0.18381427,
#  'learning_rate': 0.077626534}
# I0203 21:56:55.633824 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.04896483,
#  'Loss/localization_loss': 0.01565394,
#  'Loss/regularization_loss': 0.1191955,
#  'Loss/total_loss': 0.18381427,
#  'learning_rate': 0.077626534}
# INFO:tensorflow:Step 6500 per-step time 0.314s
# I0203 21:57:27.010736 8350614080 model_lib_v2.py:705] Step 6500 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.03373687,
#  'Loss/localization_loss': 0.010892249,
#  'Loss/regularization_loss': 0.11856216,
#  'Loss/total_loss': 0.16319127,
#  'learning_rate': 0.077538736}
# I0203 21:57:27.010866 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.03373687,
#  'Loss/localization_loss': 0.010892249,
#  'Loss/regularization_loss': 0.11856216,
#  'Loss/total_loss': 0.16319127,
#  'learning_rate': 0.077538736}
# INFO:tensorflow:Step 6600 per-step time 0.323s
# I0203 21:57:59.308229 8350614080 model_lib_v2.py:705] Step 6600 per-step time 0.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.03538843,
#  'Loss/localization_loss': 0.0118262945,
#  'Loss/regularization_loss': 0.117927074,
#  'Loss/total_loss': 0.16514179,
#  'learning_rate': 0.07744939}
# I0203 21:57:59.308357 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.03538843,
#  'Loss/localization_loss': 0.0118262945,
#  'Loss/regularization_loss': 0.117927074,
#  'Loss/total_loss': 0.16514179,
#  'learning_rate': 0.07744939}
# INFO:tensorflow:Step 6700 per-step time 0.325s
# I0203 21:58:31.814211 8350614080 model_lib_v2.py:705] Step 6700 per-step time 0.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.06903112,
#  'Loss/localization_loss': 0.014977589,
#  'Loss/regularization_loss': 0.11730312,
#  'Loss/total_loss': 0.20131183,
#  'learning_rate': 0.077358514}
# I0203 21:58:31.814347 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.06903112,
#  'Loss/localization_loss': 0.014977589,
#  'Loss/regularization_loss': 0.11730312,
#  'Loss/total_loss': 0.20131183,
#  'learning_rate': 0.077358514}
# INFO:tensorflow:Step 6800 per-step time 0.328s
# I0203 21:59:04.645353 8350614080 model_lib_v2.py:705] Step 6800 per-step time 0.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.043911353,
#  'Loss/localization_loss': 0.011870154,
#  'Loss/regularization_loss': 0.116677605,
#  'Loss/total_loss': 0.17245911,
#  'learning_rate': 0.0772661}
# I0203 21:59:04.645597 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.043911353,
#  'Loss/localization_loss': 0.011870154,
#  'Loss/regularization_loss': 0.116677605,
#  'Loss/total_loss': 0.17245911,
#  'learning_rate': 0.0772661}
# INFO:tensorflow:Step 6900 per-step time 0.334s
# ...
# I0203 22:01:58.638123 8350614080 model_lib_v2.py:705] Step 7300 per-step time 0.345s
# INFO:tensorflow:{'Loss/classification_loss': 0.066248246,
#  'Loss/localization_loss': 0.01599937,
#  'Loss/regularization_loss': 0.11362867,
#  'Loss/total_loss': 0.19587627,
#  'learning_rate': 0.07678111}
# I0203 22:01:58.638391 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.066248246,
#  'Loss/localization_loss': 0.01599937,
#  'Loss/regularization_loss': 0.11362867,
#  'Loss/total_loss': 0.19587627,
#  'learning_rate': 0.07678111}
# INFO:tensorflow:Step 7400 per-step time 0.341s
# I0203 22:02:32.762773 8350614080 model_lib_v2.py:705] Step 7400 per-step time 0.341s
# INFO:tensorflow:{'Loss/classification_loss': 0.029439433,
#  'Loss/localization_loss': 0.011339517,
#  'Loss/regularization_loss': 0.1130646,
#  'Loss/total_loss': 0.15384355,
#  'learning_rate': 0.076679565}
# I0203 22:02:32.762937 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.029439433,
#  'Loss/localization_loss': 0.011339517,
#  'Loss/regularization_loss': 0.1130646,
#  'Loss/total_loss': 0.15384355,
#  'learning_rate': 0.076679565}
# INFO:tensorflow:Step 7500 per-step time 0.349s
# I0203 22:03:07.670325 8350614080 model_lib_v2.py:705] Step 7500 per-step time 0.349s
# INFO:tensorflow:{'Loss/classification_loss': 0.06197442,
#  'Loss/localization_loss': 0.01495737,
#  'Loss/regularization_loss': 0.112463415,
#  'Loss/total_loss': 0.1893952,
#  'learning_rate': 0.0765765}
# I0203 22:03:07.670482 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.06197442,
#  'Loss/localization_loss': 0.01495737,
#  'Loss/regularization_loss': 0.112463415,
#  'Loss/total_loss': 0.1893952,
#  'learning_rate': 0.0765765}
# INFO:tensorflow:Step 7600 per-step time 0.336s
# I0203 22:03:41.261874 8350614080 model_lib_v2.py:705] Step 7600 per-step time 0.336s
# INFO:tensorflow:{'Loss/classification_loss': 0.043606903,
#  'Loss/localization_loss': 0.007750369,
#  'Loss/regularization_loss': 0.11188083,
#  'Loss/total_loss': 0.1632381,
#  'learning_rate': 0.07647194}
# I0203 22:03:41.262029 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.043606903,
#  'Loss/localization_loss': 0.007750369,
#  'Loss/regularization_loss': 0.11188083,
#  'Loss/total_loss': 0.1632381,
#  'learning_rate': 0.07647194}
# INFO:tensorflow:Step 7700 per-step time 0.336s
# I0203 22:04:14.894578 8350614080 model_lib_v2.py:705] Step 7700 per-step time 0.336s
# INFO:tensorflow:{'Loss/classification_loss': 0.025500298,
#  'Loss/localization_loss': 0.0069051194,
#  'Loss/regularization_loss': 0.11131103,
#  'Loss/total_loss': 0.14371645,
#  'learning_rate': 0.07636588}
# I0203 22:04:14.894715 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.025500298,
#  'Loss/localization_loss': 0.0069051194,
#  'Loss/regularization_loss': 0.11131103,
#  'Loss/total_loss': 0.14371645,
#  'learning_rate': 0.07636588}
# INFO:tensorflow:Step 7800 per-step time 0.337s
# I0203 22:04:48.545124 8350614080 model_lib_v2.py:705] Step 7800 per-step time 0.337s
# INFO:tensorflow:{'Loss/classification_loss': 0.034984145,
#  'Loss/localization_loss': 0.013077925,
#  'Loss/regularization_loss': 0.11073011,
#  'Loss/total_loss': 0.15879218,
#  'learning_rate': 0.07625833}
# I0203 22:04:48.545262 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.034984145,
#  'Loss/localization_loss': 0.013077925,
#  'Loss/regularization_loss': 0.11073011,
#  'Loss/total_loss': 0.15879218,
#  'learning_rate': 0.07625833}
# INFO:tensorflow:Step 7900 per-step time 0.355s
# I0203 22:05:24.053688 8350614080 model_lib_v2.py:705] Step 7900 per-step time 0.355s
# INFO:tensorflow:{'Loss/classification_loss': 0.038547598,
#  'Loss/localization_loss': 0.0071561113,
#  'Loss/regularization_loss': 0.11014835,
#  'Loss/total_loss': 0.15585205,
#  'learning_rate': 0.07614928}
# I0203 22:05:24.053838 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.038547598,
#  'Loss/localization_loss': 0.0071561113,
#  'Loss/regularization_loss': 0.11014835,
#  'Loss/total_loss': 0.15585205,
#  'learning_rate': 0.07614928}
# INFO:tensorflow:Step 8000 per-step time 0.358s
# I0203 22:05:59.895467 8350614080 model_lib_v2.py:705] Step 8000 per-step time 0.358s
# INFO:tensorflow:{'Loss/classification_loss': 0.029653342,
#  'Loss/localization_loss': 0.009172335,
#  'Loss/regularization_loss': 0.10957338,
#  'Loss/total_loss': 0.14839906,
#  'learning_rate': 0.07603875}
# I0203 22:05:59.895623 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.029653342,
#  'Loss/localization_loss': 0.009172335,
#  'Loss/regularization_loss': 0.10957338,
#  'Loss/total_loss': 0.14839906,
#  'learning_rate': 0.07603875}
# INFO:tensorflow:Step 8100 per-step time 0.349s
# I0203 22:06:34.790896 8350614080 model_lib_v2.py:705] Step 8100 per-step time 0.349s
# INFO:tensorflow:{'Loss/classification_loss': 0.083312064,
#  'Loss/localization_loss': 0.009800729,
#  'Loss/regularization_loss': 0.1089823,
#  'Loss/total_loss': 0.20209509,
#  'learning_rate': 0.07592674}
# I0203 22:06:34.791077 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.083312064,
#  'Loss/localization_loss': 0.009800729,
#  'Loss/regularization_loss': 0.1089823,
#  'Loss/total_loss': 0.20209509,
#  'learning_rate': 0.07592674}
# INFO:tensorflow:Step 8200 per-step time 0.361s
# I0203 22:07:10.881587 8350614080 model_lib_v2.py:705] Step 8200 per-step time 0.361s
# INFO:tensorflow:{'Loss/classification_loss': 0.06716912,
#  'Loss/localization_loss': 0.011422864,
#  'Loss/regularization_loss': 0.108432874,
#  'Loss/total_loss': 0.18702486,
#  'learning_rate': 0.075813256}
# I0203 22:07:10.881736 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.06716912,
#  'Loss/localization_loss': 0.011422864,
#  'Loss/regularization_loss': 0.108432874,
#  'Loss/total_loss': 0.18702486,
#  'learning_rate': 0.075813256}
# INFO:tensorflow:Step 8300 per-step time 0.362s
# I0203 22:07:47.068397 8350614080 model_lib_v2.py:705] Step 8300 per-step time 0.362s
# INFO:tensorflow:{'Loss/classification_loss': 0.061538007,
#  'Loss/localization_loss': 0.009174928,
#  'Loss/regularization_loss': 0.10787475,
#  'Loss/total_loss': 0.17858769,
#  'learning_rate': 0.07569829}
# I0203 22:07:47.068654 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.061538007,
#  'Loss/localization_loss': 0.009174928,
#  'Loss/regularization_loss': 0.10787475,
#  'Loss/total_loss': 0.17858769,
#  'learning_rate': 0.07569829}
# INFO:tensorflow:Step 8400 per-step time 0.357s
# I0203 22:08:22.731535 8350614080 model_lib_v2.py:705] Step 8400 per-step time 0.357s
# INFO:tensorflow:{'Loss/classification_loss': 0.028303012,
#  'Loss/localization_loss': 0.009280308,
#  'Loss/regularization_loss': 0.10730409,
#  'Loss/total_loss': 0.14488742,
#  'learning_rate': 0.07558186}
# I0203 22:08:22.731682 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.028303012,
#  'Loss/localization_loss': 0.009280308,
#  'Loss/regularization_loss': 0.10730409,
#  'Loss/total_loss': 0.14488742,
#  'learning_rate': 0.07558186}
# INFO:tensorflow:Step 8500 per-step time 0.366s
# I0203 22:08:59.343738 8350614080 model_lib_v2.py:705] Step 8500 per-step time 0.366s
# INFO:tensorflow:{'Loss/classification_loss': 0.046425663,
#  'Loss/localization_loss': 0.009790844,
#  'Loss/regularization_loss': 0.10675694,
#  'Loss/total_loss': 0.16297345,
#  'learning_rate': 0.07546397}
# I0203 22:08:59.343990 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.046425663,
#  'Loss/localization_loss': 0.009790844,
#  'Loss/regularization_loss': 0.10675694,
#  'Loss/total_loss': 0.16297345,
#  'learning_rate': 0.07546397}
# INFO:tensorflow:Step 8600 per-step time 0.365s
# I0203 22:09:35.815797 8350614080 model_lib_v2.py:705] Step 8600 per-step time 0.365s
# INFO:tensorflow:{'Loss/classification_loss': 0.051002845,
#  'Loss/localization_loss': 0.016483707,
#  'Loss/regularization_loss': 0.10619964,
#  'Loss/total_loss': 0.17368619,
#  'learning_rate': 0.075344615}
# I0203 22:09:35.815941 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.051002845,
#  'Loss/localization_loss': 0.016483707,
#  'Loss/regularization_loss': 0.10619964,
#  'Loss/total_loss': 0.17368619,
#  'learning_rate': 0.075344615}
# INFO:tensorflow:Step 8700 per-step time 0.363s
# I0203 22:10:12.079714 8350614080 model_lib_v2.py:705] Step 8700 per-step time 0.363s
# INFO:tensorflow:{'Loss/classification_loss': 0.044036213,
#  'Loss/localization_loss': 0.0065687983,
#  'Loss/regularization_loss': 0.10566605,
#  'Loss/total_loss': 0.15627106,
#  'learning_rate': 0.07522382}
# I0203 22:10:12.079874 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.044036213,
#  'Loss/localization_loss': 0.0065687983,
#  'Loss/regularization_loss': 0.10566605,
#  'Loss/total_loss': 0.15627106,
#  'learning_rate': 0.07522382}
# INFO:tensorflow:Step 8800 per-step time 0.369s
# I0203 22:10:48.979180 8350614080 model_lib_v2.py:705] Step 8800 per-step time 0.369s
# INFO:tensorflow:{'Loss/classification_loss': 0.03704835,
#  'Loss/localization_loss': 0.014427388,
#  'Loss/regularization_loss': 0.105130814,
#  'Loss/total_loss': 0.15660655,
#  'learning_rate': 0.07510157}
# I0203 22:10:48.979346 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.03704835,
#  'Loss/localization_loss': 0.014427388,
#  'Loss/regularization_loss': 0.105130814,
#  'Loss/total_loss': 0.15660655,
#  'learning_rate': 0.07510157}
# INFO:tensorflow:Step 8900 per-step time 0.367s
# I0203 22:11:25.649226 8350614080 model_lib_v2.py:705] Step 8900 per-step time 0.367s
# INFO:tensorflow:{'Loss/classification_loss': 0.0955452,
#  'Loss/localization_loss': 0.0336889,
#  'Loss/regularization_loss': 0.10459342,
#  'Loss/total_loss': 0.23382753,
#  'learning_rate': 0.074977875}
# I0203 22:11:25.649378 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.0955452,
#  'Loss/localization_loss': 0.0336889,
#  'Loss/regularization_loss': 0.10459342,
#  'Loss/total_loss': 0.23382753,
#  'learning_rate': 0.074977875}
# INFO:tensorflow:Step 9000 per-step time 0.373s
# I0203 22:12:02.943909 8350614080 model_lib_v2.py:705] Step 9000 per-step time 0.373s
# INFO:tensorflow:{'Loss/classification_loss': 0.100260824,
#  'Loss/localization_loss': 0.011802041,
#  'Loss/regularization_loss': 0.10405791,
#  'Loss/total_loss': 0.21612078,
#  'learning_rate': 0.07485275}
# I0203 22:12:02.944077 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.100260824,
#  'Loss/localization_loss': 0.011802041,
#  'Loss/regularization_loss': 0.10405791,
#  'Loss/total_loss': 0.21612078,
#  'learning_rate': 0.07485275}
# INFO:tensorflow:Step 9100 per-step time 0.366s
# I0203 22:12:39.593027 8350614080 model_lib_v2.py:705] Step 9100 per-step time 0.366s
# INFO:tensorflow:{'Loss/classification_loss': 0.07430007,
#  'Loss/localization_loss': 0.010690944,
#  'Loss/regularization_loss': 0.10380038,
#  'Loss/total_loss': 0.1887914,
#  'learning_rate': 0.07472619}
# I0203 22:12:39.593221 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.07430007,
#  'Loss/localization_loss': 0.010690944,
#  'Loss/regularization_loss': 0.10380038,
#  'Loss/total_loss': 0.1887914,
#  'learning_rate': 0.07472619}
# INFO:tensorflow:Step 9200 per-step time 0.390s
# I0203 22:13:18.570703 8350614080 model_lib_v2.py:705] Step 9200 per-step time 0.390s
# INFO:tensorflow:{'Loss/classification_loss': 0.029167386,
#  'Loss/localization_loss': 0.007050463,
#  'Loss/regularization_loss': 0.103296205,
#  'Loss/total_loss': 0.13951406,
#  'learning_rate': 0.07459819}
# I0203 22:13:18.570892 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.029167386,
#  'Loss/localization_loss': 0.007050463,
#  'Loss/regularization_loss': 0.103296205,
#  'Loss/total_loss': 0.13951406,
#  'learning_rate': 0.07459819}
# INFO:tensorflow:Step 9300 per-step time 0.375s
# I0203 22:13:56.088496 8350614080 model_lib_v2.py:705] Step 9300 per-step time 0.375s
# INFO:tensorflow:{'Loss/classification_loss': 0.030997612,
#  'Loss/localization_loss': 0.012690173,
#  'Loss/regularization_loss': 0.10276949,
#  'Loss/total_loss': 0.14645727,
#  'learning_rate': 0.074468784}
# I0203 22:13:56.088654 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.030997612,
#  'Loss/localization_loss': 0.012690173,
#  'Loss/regularization_loss': 0.10276949,
#  'Loss/total_loss': 0.14645727,
#  'learning_rate': 0.074468784}
# INFO:tensorflow:Step 9400 per-step time 0.374s
# I0203 22:14:33.489290 8350614080 model_lib_v2.py:705] Step 9400 per-step time 0.374s
# INFO:tensorflow:{'Loss/classification_loss': 0.028639907,
#  'Loss/localization_loss': 0.016088134,
#  'Loss/regularization_loss': 0.10224677,
#  'Loss/total_loss': 0.1469748,
#  'learning_rate': 0.074337944}
# I0203 22:14:33.489440 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.028639907,
#  'Loss/localization_loss': 0.016088134,
#  'Loss/regularization_loss': 0.10224677,
#  'Loss/total_loss': 0.1469748,
#  'learning_rate': 0.074337944}
# INFO:tensorflow:Step 9500 per-step time 0.401s
# I0203 22:15:13.626863 8350614080 model_lib_v2.py:705] Step 9500 per-step time 0.401s
# INFO:tensorflow:{'Loss/classification_loss': 0.036126763,
#  'Loss/localization_loss': 0.017640382,
#  'Loss/regularization_loss': 0.101728566,
#  'Loss/total_loss': 0.1554957,
#  'learning_rate': 0.074205704}
# I0203 22:15:13.627025 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.036126763,
#  'Loss/localization_loss': 0.017640382,
#  'Loss/regularization_loss': 0.101728566,
#  'Loss/total_loss': 0.1554957,
#  'learning_rate': 0.074205704}
# INFO:tensorflow:Step 9600 per-step time 0.392s
# I0203 22:15:52.827502 8350614080 model_lib_v2.py:705] Step 9600 per-step time 0.392s
# INFO:tensorflow:{'Loss/classification_loss': 0.032148488,
#  'Loss/localization_loss': 0.0062565943,
#  'Loss/regularization_loss': 0.10119522,
#  'Loss/total_loss': 0.1396003,
#  'learning_rate': 0.07407206}
# I0203 22:15:52.827664 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.032148488,
#  'Loss/localization_loss': 0.0062565943,
#  'Loss/regularization_loss': 0.10119522,
#  'Loss/total_loss': 0.1396003,
#  'learning_rate': 0.07407206}
# INFO:tensorflow:Step 9700 per-step time 0.381s
# I0203 22:16:30.881217 8350614080 model_lib_v2.py:705] Step 9700 per-step time 0.381s
# INFO:tensorflow:{'Loss/classification_loss': 0.020738728,
#  'Loss/localization_loss': 0.007944283,
#  'Loss/regularization_loss': 0.10067007,
#  'Loss/total_loss': 0.12935308,
#  'learning_rate': 0.073937014}
# I0203 22:16:30.881372 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.020738728,
#  'Loss/localization_loss': 0.007944283,
#  'Loss/regularization_loss': 0.10067007,
#  'Loss/total_loss': 0.12935308,
#  'learning_rate': 0.073937014}
# INFO:tensorflow:Step 9800 per-step time 0.414s
# I0203 22:17:12.290178 8350614080 model_lib_v2.py:705] Step 9800 per-step time 0.414s
# INFO:tensorflow:{'Loss/classification_loss': 0.01902794,
#  'Loss/localization_loss': 0.0051156133,
#  'Loss/regularization_loss': 0.10015358,
#  'Loss/total_loss': 0.124297135,
#  'learning_rate': 0.07380057}
# I0203 22:17:12.290338 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.01902794,
#  'Loss/localization_loss': 0.0051156133,
#  'Loss/regularization_loss': 0.10015358,
#  'Loss/total_loss': 0.124297135,
#  'learning_rate': 0.07380057}
# INFO:tensorflow:Step 9900 per-step time 0.399s
# I0203 22:17:52.191077 8350614080 model_lib_v2.py:705] Step 9900 per-step time 0.399s
# INFO:tensorflow:{'Loss/classification_loss': 0.060161043,
#  'Loss/localization_loss': 0.009393253,
#  'Loss/regularization_loss': 0.0996623,
#  'Loss/total_loss': 0.1692166,
#  'learning_rate': 0.073662736}
# I0203 22:17:52.191350 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.060161043,
#  'Loss/localization_loss': 0.009393253,
#  'Loss/regularization_loss': 0.0996623,
#  'Loss/total_loss': 0.1692166,
#  'learning_rate': 0.073662736}
# INFO:tensorflow:Step 10000 per-step time 0.394s
# I0203 22:18:31.620681 8350614080 model_lib_v2.py:705] Step 10000 per-step time 0.394s
# INFO:tensorflow:{'Loss/classification_loss': 0.07834745,
#  'Loss/localization_loss': 0.008290167,
#  'Loss/regularization_loss': 0.09916828,
#  'Loss/total_loss': 0.18580589,
#  'learning_rate': 0.07352352}
# I0203 22:18:31.620858 8350614080 model_lib_v2.py:708] {'Loss/classification_loss': 0.07834745,
#  'Loss/localization_loss': 0.008290167,
#  'Loss/regularization_loss': 0.09916828,
#  'Loss/total_loss': 0.18580589,
#  'learning_rate': 0.07352352}

# %% [markdown]
# # 7. LOAD trained model from checkpoint

# %%
import os
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
# UPDATE ckpt-XX to latest checkpoint
ckpt.restore(os.path.join(CHECKPOINT_PATH, 'ckpt-11')).expect_partial() 

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 8 - RTOD pretrained sign language gloss detection

# %%
import cv2
import numpy as np
# added to ensure stream closes properly
import tensorflow as tf
from object_detection.utils import visualization_utils as viz_utils

# %%
category_index = label_map_util.create_category_index_from_labelmap(ANNOTATION_PATH+'/label_map.pbtxt')

# %%
# Setup capture
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
# start webcam and log detected objects with confidence score

import cv2
import numpy as np
import tensorflow as tf
from object_detection.utils import visualization_utils as viz_utils
import time

# Define a function to log detected objects
def log_detected_objects(detections, category_index):
    log = []
    for i in range(detections['num_detections']):
        if detections['detection_scores'][i] >= 0.8:
            class_id = detections['detection_classes'][i]
            if class_id in category_index:
                class_name = category_index[class_id]['name']
                score = detections['detection_scores'][i]
                log.append((class_name, score))
    return log

# Initialize logging list
detected_objects_log = []
last_log_time = time.time()

# Initialize the camera
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video source.")
else:
    try:
        while True: 
            ret, frame = cap.read()
            if not ret:
                print("Error: Failed to capture frame.")
                break

            image_np = np.array(frame)
            
            input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
            detections = detect_fn(input_tensor)
            
            num_detections = int(detections.pop('num_detections'))
            detections = {key: value[0, :num_detections].numpy()
                          for key, value in detections.items()}
            detections['num_detections'] = num_detections

            # detection_classes should be ints.
            detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

            label_id_offset = 1
            image_np_with_detections = image_np.copy()

            viz_utils.visualize_boxes_and_labels_on_image_array(
                        image_np_with_detections,
                        detections['detection_boxes'],
                        detections['detection_classes'] + label_id_offset,
                        detections['detection_scores'],
                        category_index,
                        use_normalized_coordinates=True,
                        max_boxes_to_draw=5,
                        min_score_thresh=.5,
                        agnostic_mode=False)

            cv2.imshow('object detection', cv2.resize(image_np_with_detections, (800, 600)))

            # Log detected objects with a score of over 80%, but only once every second
            current_time = time.time()
            if current_time - last_log_time >= 1:
                logged_objects = log_detected_objects(detections, category_index)
                detected_objects_log.extend(logged_objects)
                print(f"Logged objects: {logged_objects}")  # Print the logged objects with confidence scores
                last_log_time = current_time
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    finally:
        cap.release()
        cv2.destroyAllWindows()
        # Print the log of detected objects in list format
        detected_objects = [(entry[0], entry[1]) for entry in detected_objects_log]
        print(f"\ndetected_objects_log = {detected_objects}")
# Out:
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: [('yes', 0.81171584)]
# Logged objects: [('thanks', 0.96582884)]
# Logged objects: [('thanks', 0.8597149)]
# Logged objects: [('thanks', 0.9724091)]
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: [('yes', 0.88370776)]
# Logged objects: []
#
# detected_objects_log = [('yes', 0.81171584), ('thanks', 0.96582884), ('thanks', 0.8597149), ('thanks', 0.9724091), ('yes', 0.88370776)]

# %%
# remove duplicates/ objects appearing multiple times after each other
def remove_consecutive_duplicates(detected_objects):
    return [detected_objects[i] for i in range(len(detected_objects)) if i == 0 or detected_objects[i][0] != detected_objects[i-1][0]]

# Create cleaned_detected_objects_log
cleaned_detected_objects_log = remove_consecutive_duplicates(detected_objects_log)

# Print the cleaned objects
print(f"\ncleaned_detected_objects_log = {cleaned_detected_objects_log}")
# Out:
# cleaned_detected_objects_log = [('yes', 0.81171584), ('thanks', 0.96582884), ('yes', 0.88370776)]

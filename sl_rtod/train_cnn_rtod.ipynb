# %% [markdown]
# Resources Used
# - wget.download('https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/_downloads/da4babe668a8afb093cc7776d7e630f3/generate_tfrecord.py')
# - Setup https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html

# %% [markdown]
# # 0. LOAD virtual environment

# %%
# terminal command - isntall requirements txt
pip install -r requirements.txt

# %% [markdown]
# # 1. SETUP paths

# %%
WORKSPACE_PATH = 'Tensorflow/workspace'
SCRIPTS_PATH = 'Tensorflow/scripts'
APIMODEL_PATH = 'Tensorflow/models'
ANNOTATION_PATH = WORKSPACE_PATH+'/annotations'
IMAGE_PATH = WORKSPACE_PATH+'/images'
MODEL_PATH = WORKSPACE_PATH+'/models'
PRETRAINED_MODEL_PATH = WORKSPACE_PATH+'/pre-trained-models'
CONFIG_PATH = MODEL_PATH+'/my_ssd_mobnet/pipeline.config'
CHECKPOINT_PATH = MODEL_PATH+'/my_ssd_mobnet/'

# %% [markdown]
# # 2. CREATE label maps

# %%
# create the dictionary entries for all glosses the model shall be trained on - MAKE SURE the naming exactly matches labelimg - ad add sequential IDs
labels = [
    {'name':'hello', 'id':1}, 
    {'name':'yes', 'id':2}, 
    {'name':'no', 'id':3}, 
    {'name':'thanks', 'id':4}, 
    {'name':'i love you', 'id':5}, 
    {'name':'montag', 'id':6},    
    {'name':'auch', 'id':7},  
    {'name':'mehr', 'id':8},  
    {'name':'wolke', 'id':9},  
    {'name':'als', 'id':10},  
    {'name':'sonne', 'id':11},  
    {'name':'ueberwiegend', 'id':12},  
    {'name':'regen', 'id':13},  
    {'name':'gewitter', 'id':14},  
    ]

with open(ANNOTATION_PATH + '/label_map.pbtxt', 'w') as f:
    for label in labels:
        f.write('item {\n') # space removed
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. CREATE tfrecord file

# %%
# downloading pretrained tf models from tf model zoo
# !cd Tensorflow && git clone https://github.com/tensorflow/models
# Out:
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
# installing object detection module (see command box below, keeping comment & command in same code created issues)

# %%
# %%bash
# cd Tensorflow/models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf1/setup.py . # updated to tf1
# python -m pip install .
# Out:
# Processing /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/Tensorflow/models/research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pillow in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (11.1.0)
# Requirement already satisfied: lxml in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (5.3.0)
# Requirement already satisfied: matplotlib in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (3.10.0)
# Requirement already satisfied: Cython in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (3.0.11)
# Requirement already satisfied: contextlib2 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.1.0)
# Requirement already satisfied: six in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.17.0)
# Requirement already satisfied: pycocotools in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (2.0.8)
# Requirement already satisfied: lvis in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (1.15.1)
# Requirement already satisfied: pandas in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from object_detection==0.1) (2.2.3)
# Requirement already satisfied: cycler>=0.10.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (1.4.8)
# Requirement already satisfied: numpy>=1.18.2 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (4.11.0.86)
# Requirement already satisfied: pyparsing>=2.4.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from lvis->object_detection==0.1) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (4.55.8)
# Requirement already satisfied: packaging>=20.0 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (24.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2025.1)
# Requirement already satisfied: absl-py>=0.2.2 in /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages (from tf-slim->object_detection==0.1) (1.4.0)
# Building wheels for collected packages: object_detection
#   Building wheel for object_detection (setup.py): started
#   Building wheel for object_detection (setup.py): finished with status 'done'
#   Created wheel for object_detection: filename=object_detection-0.1-py3-none-any.whl size=1656739 sha256=6eea508b585e528bd92de887dc1a7dce0bb9357fe6559885cf18c0f8bcdd9ad6
#   Stored in directory: /private/var/folders/y5/l0vddhks2fj4y_tkywmly1240000gn/T/pip-ephem-wheel-cache-6l3oe12u/wheels/ed/f4/6c/bcb9019e476a83fa88035201dd62b698e5d335557fa45a84a6
# Successfully built object_detection
# Installing collected packages: object_detection
#   Attempting uninstall: object_detection
#     Found existing installation: object_detection 0.1
#     Uninstalling object_detection-0.1:
#       Successfully uninstalled object_detection-0.1
# Successfully installed object_detection-0.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
# update line of code in .venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py

"""
replace
from tensorflow.python.keras.layers.preprocessing import image_preprocessing as image_ops 
with
from tensorflow.keras.preprocessing import image as image_ops
"""


import os

# Define the path to the Python file
file_path = ".venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py"

# Define the lines to be replaced
old_line = "from tensorflow.python.keras.layers.preprocessing import image_preprocessing as image_ops"
new_line = "from tensorflow.keras.preprocessing import image as image_ops"

# Read the file and copy the old line as a comment, then add the new line
with open(file_path, 'r') as file:
    lines = file.readlines()

with open(file_path, 'w') as file:
    for line in lines:
        if old_line in line:
            file.write("# " + line)  # Comment out the old line
            file.write(new_line + '\n')  # Add the new line
        else:
            file.write(line)

print(f"Updated {file_path} with new import statement and commented out the old one.")
# Out:
# Updated .venv/lib/python3.10/site-packages/official/vision/image_classification/augment.py with new import statement and commented out the old one.

# %%
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x{IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. COPY model config to training folder

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' # model rerun with augmented training data - folder Tensorflow/models/my_ssd_mobnet needs to be deleted otherwise training model script will throw an error

# %%
# !mkdir -p {'Tensorflow/workspace/models/' + CUSTOM_MODEL_NAME}
# !cp {PRETRAINED_MODEL_PATH + '/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config'} {MODEL_PATH + '/' + CUSTOM_MODEL_NAME}

# %% [markdown]
# # 5. UPDATE config for transfer learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
CONFIG_PATH = MODEL_PATH+'/'+CUSTOM_MODEL_NAME+'/pipeline.config'

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 4e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.01
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.997
#          scale: true
#          epsilon: 0.001
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 4e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.01
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.997
#            scale: true
#            epsilon: 0.001
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.6
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 1e-08
#        iou_threshold: 0.6
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.08
#          total_steps: 50000
#          warmup_learning_rate: 0.026666
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.9
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %% [markdown]
# !!! UPDATE no. of glosses

# %%
pipeline_config.model.ssd.num_classes = 14 # UPDATE to the number of classes your model shall be trained on
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/train.record']
pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. TRAIN the model

# %%
# no. of steps set to 10000
print("""python {}/research/object_detection/model_main_tf2.py --model_dir={}/{} --pipeline_config_path={}/{}/pipeline.config --num_train_steps=10000""".format(APIMODEL_PATH, MODEL_PATH,CUSTOM_MODEL_NAME,MODEL_PATH,CUSTOM_MODEL_NAME))
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=10000

# %%
# copy paste python command to run the model 
# !python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=10000
# Out:
# /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0204 12:09:28.787529 8464107584 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I0204 12:09:28.799954 8464107584 config_util.py:552] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0204 12:09:28.800027 8464107584 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0204 12:09:28.813077 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0204 12:09:28.817167 8464107584 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0204 12:09:28.817221 8464107584 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0204 12:09:28.817243 8464107584 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0204 12:09:28.817262 8464107584 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0204 12:09:28.821547 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0204 12:09:28.832341 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0204 12:09:31.915571 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0204 12:09:33.283859 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0204 12:09:34.018013 8464107584 deprecation.py:364] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2025-02-04 12:09:35.363339: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0204 12:09:38.236779 14378102784 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0204 12:09:41.754810 14432628736 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0204 12:09:44.943790 14682091520 deprecation.py:569] From /Users/maximilianscheel/neuefische/capstone_project/capstone_sl_txt_voice/sl_rtod/.venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0204 12:09:45.393486 14682091520 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0204 12:09:47.680622 14746152960 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0204 12:09:49.839336 14844719104 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0204 12:09:52.161747 14959013888 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.525s
# I0204 12:10:36.921056 8464107584 model_lib_v2.py:705] Step 100 per-step time 0.525s
# INFO:tensorflow:{'Loss/classification_loss': 0.55179375,
#  'Loss/localization_loss': 0.3779992,
#  'Loss/regularization_loss': 0.15387656,
#  'Loss/total_loss': 1.0836694,
#  'learning_rate': 0.0319994}
# I0204 12:10:36.921807 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.55179375,
#  'Loss/localization_loss': 0.3779992,
#  'Loss/regularization_loss': 0.15387656,
#  'Loss/total_loss': 1.0836694,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.385s
# I0204 12:11:15.447708 8464107584 model_lib_v2.py:705] Step 200 per-step time 0.385s
# INFO:tensorflow:{'Loss/classification_loss': 0.5270637,
#  'Loss/localization_loss': 0.3543963,
#  'Loss/regularization_loss': 0.15409817,
#  'Loss/total_loss': 1.0355582,
#  'learning_rate': 0.0373328}
# I0204 12:11:15.447936 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.5270637,
#  'Loss/localization_loss': 0.3543963,
#  'Loss/regularization_loss': 0.15409817,
#  'Loss/total_loss': 1.0355582,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.353s
# I0204 12:11:50.779721 8464107584 model_lib_v2.py:705] Step 300 per-step time 0.353s
# INFO:tensorflow:{'Loss/classification_loss': 0.35316026,
#  'Loss/localization_loss': 0.13797957,
#  'Loss/regularization_loss': 0.15414456,
#  'Loss/total_loss': 0.64528435,
#  'learning_rate': 0.0426662}
# I0204 12:11:50.780273 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.35316026,
#  'Loss/localization_loss': 0.13797957,
#  'Loss/regularization_loss': 0.15414456,
#  'Loss/total_loss': 0.64528435,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.352s
# I0204 12:12:25.955162 8464107584 model_lib_v2.py:705] Step 400 per-step time 0.352s
# INFO:tensorflow:{'Loss/classification_loss': 0.4691,
#  'Loss/localization_loss': 0.23658565,
#  'Loss/regularization_loss': 0.15401582,
#  'Loss/total_loss': 0.85970145,
#  'learning_rate': 0.047999598}
# I0204 12:12:25.955311 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.4691,
#  'Loss/localization_loss': 0.23658565,
#  'Loss/regularization_loss': 0.15401582,
#  'Loss/total_loss': 0.85970145,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.353s
# I0204 12:13:01.274532 8464107584 model_lib_v2.py:705] Step 500 per-step time 0.353s
# INFO:tensorflow:{'Loss/classification_loss': 0.4463317,
#  'Loss/localization_loss': 0.19259991,
#  'Loss/regularization_loss': 0.15404494,
#  'Loss/total_loss': 0.79297656,
#  'learning_rate': 0.053333}
# I0204 12:13:01.274684 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.4463317,
#  'Loss/localization_loss': 0.19259991,
#  'Loss/regularization_loss': 0.15404494,
#  'Loss/total_loss': 0.79297656,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.386s
# I0204 12:13:39.915645 8464107584 model_lib_v2.py:705] Step 600 per-step time 0.386s
# INFO:tensorflow:{'Loss/classification_loss': 0.40472296,
#  'Loss/localization_loss': 0.14818043,
#  'Loss/regularization_loss': 0.1541899,
#  'Loss/total_loss': 0.70709324,
#  'learning_rate': 0.0586664}
# I0204 12:13:39.916239 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.40472296,
#  'Loss/localization_loss': 0.14818043,
#  'Loss/regularization_loss': 0.1541899,
#  'Loss/total_loss': 0.70709324,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.413s
# I0204 12:14:21.188423 8464107584 model_lib_v2.py:705] Step 700 per-step time 0.413s
# INFO:tensorflow:{'Loss/classification_loss': 0.47006252,
#  'Loss/localization_loss': 0.14928643,
#  'Loss/regularization_loss': 0.15408705,
#  'Loss/total_loss': 0.773436,
#  'learning_rate': 0.0639998}
# I0204 12:14:21.188721 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.47006252,
#  'Loss/localization_loss': 0.14928643,
#  'Loss/regularization_loss': 0.15408705,
#  'Loss/total_loss': 0.773436,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.377s
# I0204 12:14:58.847204 8464107584 model_lib_v2.py:705] Step 800 per-step time 0.377s
# INFO:tensorflow:{'Loss/classification_loss': 0.22030342,
#  'Loss/localization_loss': 0.14937961,
#  'Loss/regularization_loss': 0.15389195,
#  'Loss/total_loss': 0.52357495,
#  'learning_rate': 0.069333196}
# I0204 12:14:58.847450 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.22030342,
#  'Loss/localization_loss': 0.14937961,
#  'Loss/regularization_loss': 0.15389195,
#  'Loss/total_loss': 0.52357495,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.367s
# I0204 12:15:35.536384 8464107584 model_lib_v2.py:705] Step 900 per-step time 0.367s
# INFO:tensorflow:{'Loss/classification_loss': 0.18836655,
#  'Loss/localization_loss': 0.13602668,
#  'Loss/regularization_loss': 0.15390612,
#  'Loss/total_loss': 0.47829932,
#  'learning_rate': 0.074666604}
# I0204 12:15:35.536537 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.18836655,
#  'Loss/localization_loss': 0.13602668,
#  'Loss/regularization_loss': 0.15390612,
#  'Loss/total_loss': 0.47829932,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.359s
# I0204 12:16:11.481791 8464107584 model_lib_v2.py:705] Step 1000 per-step time 0.359s
# INFO:tensorflow:{'Loss/classification_loss': 0.15696375,
#  'Loss/localization_loss': 0.11046179,
#  'Loss/regularization_loss': 0.15379703,
#  'Loss/total_loss': 0.42122257,
#  'learning_rate': 0.08}
# I0204 12:16:11.481944 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.15696375,
#  'Loss/localization_loss': 0.11046179,
#  'Loss/regularization_loss': 0.15379703,
#  'Loss/total_loss': 0.42122257,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.377s
# I0204 12:16:49.135238 8464107584 model_lib_v2.py:705] Step 1100 per-step time 0.377s
# INFO:tensorflow:{'Loss/classification_loss': 0.18382487,
#  'Loss/localization_loss': 0.06685959,
#  'Loss/regularization_loss': 0.15345609,
#  'Loss/total_loss': 0.40414053,
#  'learning_rate': 0.07999918}
# I0204 12:16:49.135426 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.18382487,
#  'Loss/localization_loss': 0.06685959,
#  'Loss/regularization_loss': 0.15345609,
#  'Loss/total_loss': 0.40414053,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.377s
# I0204 12:17:26.789570 8464107584 model_lib_v2.py:705] Step 1200 per-step time 0.377s
# INFO:tensorflow:{'Loss/classification_loss': 0.12445436,
#  'Loss/localization_loss': 0.04851116,
#  'Loss/regularization_loss': 0.15300849,
#  'Loss/total_loss': 0.32597402,
#  'learning_rate': 0.079996705}
# I0204 12:17:26.790233 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12445436,
#  'Loss/localization_loss': 0.04851116,
#  'Loss/regularization_loss': 0.15300849,
#  'Loss/total_loss': 0.32597402,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.369s
# I0204 12:18:03.644390 8464107584 model_lib_v2.py:705] Step 1300 per-step time 0.369s
# INFO:tensorflow:{'Loss/classification_loss': 0.20387141,
#  'Loss/localization_loss': 0.047237765,
#  'Loss/regularization_loss': 0.15253514,
#  'Loss/total_loss': 0.40364432,
#  'learning_rate': 0.0799926}
# I0204 12:18:03.644576 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.20387141,
#  'Loss/localization_loss': 0.047237765,
#  'Loss/regularization_loss': 0.15253514,
#  'Loss/total_loss': 0.40364432,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.362s
# I0204 12:18:39.822044 8464107584 model_lib_v2.py:705] Step 1400 per-step time 0.362s
# INFO:tensorflow:{'Loss/classification_loss': 0.17469028,
#  'Loss/localization_loss': 0.0582535,
#  'Loss/regularization_loss': 0.15189353,
#  'Loss/total_loss': 0.3848373,
#  'learning_rate': 0.07998685}
# I0204 12:18:39.822592 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.17469028,
#  'Loss/localization_loss': 0.0582535,
#  'Loss/regularization_loss': 0.15189353,
#  'Loss/total_loss': 0.3848373,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.384s
# I0204 12:19:18.261801 8464107584 model_lib_v2.py:705] Step 1500 per-step time 0.384s
# INFO:tensorflow:{'Loss/classification_loss': 0.16029601,
#  'Loss/localization_loss': 0.09480717,
#  'Loss/regularization_loss': 0.15138045,
#  'Loss/total_loss': 0.40648362,
#  'learning_rate': 0.07997945}
# I0204 12:19:18.261986 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.16029601,
#  'Loss/localization_loss': 0.09480717,
#  'Loss/regularization_loss': 0.15138045,
#  'Loss/total_loss': 0.40648362,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.392s
# I0204 12:19:57.442764 8464107584 model_lib_v2.py:705] Step 1600 per-step time 0.392s
# INFO:tensorflow:{'Loss/classification_loss': 0.13244888,
#  'Loss/localization_loss': 0.07548884,
#  'Loss/regularization_loss': 0.15098199,
#  'Loss/total_loss': 0.3589197,
#  'learning_rate': 0.079970405}
# I0204 12:19:57.443046 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.13244888,
#  'Loss/localization_loss': 0.07548884,
#  'Loss/regularization_loss': 0.15098199,
#  'Loss/total_loss': 0.3589197,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.389s
# I0204 12:20:36.344372 8464107584 model_lib_v2.py:705] Step 1700 per-step time 0.389s
# INFO:tensorflow:{'Loss/classification_loss': 0.16115525,
#  'Loss/localization_loss': 0.04331126,
#  'Loss/regularization_loss': 0.15051563,
#  'Loss/total_loss': 0.35498214,
#  'learning_rate': 0.07995972}
# I0204 12:20:36.344560 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.16115525,
#  'Loss/localization_loss': 0.04331126,
#  'Loss/regularization_loss': 0.15051563,
#  'Loss/total_loss': 0.35498214,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.404s
# I0204 12:21:16.764154 8464107584 model_lib_v2.py:705] Step 1800 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.086635254,
#  'Loss/localization_loss': 0.039469328,
#  'Loss/regularization_loss': 0.14990096,
#  'Loss/total_loss': 0.27600554,
#  'learning_rate': 0.0799474}
# I0204 12:21:16.764405 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.086635254,
#  'Loss/localization_loss': 0.039469328,
#  'Loss/regularization_loss': 0.14990096,
#  'Loss/total_loss': 0.27600554,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.423s
# I0204 12:21:59.059610 8464107584 model_lib_v2.py:705] Step 1900 per-step time 0.423s
# INFO:tensorflow:{'Loss/classification_loss': 0.11948673,
#  'Loss/localization_loss': 0.05422061,
#  'Loss/regularization_loss': 0.14921765,
#  'Loss/total_loss': 0.32292497,
#  'learning_rate': 0.07993342}
# I0204 12:21:59.059791 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11948673,
#  'Loss/localization_loss': 0.05422061,
#  'Loss/regularization_loss': 0.14921765,
#  'Loss/total_loss': 0.32292497,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.549s
# I0204 12:22:53.973731 8464107584 model_lib_v2.py:705] Step 2000 per-step time 0.549s
# INFO:tensorflow:{'Loss/classification_loss': 0.28266343,
#  'Loss/localization_loss': 0.07303453,
#  'Loss/regularization_loss': 0.14854097,
#  'Loss/total_loss': 0.50423896,
#  'learning_rate': 0.07991781}
# I0204 12:22:53.974524 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.28266343,
#  'Loss/localization_loss': 0.07303453,
#  'Loss/regularization_loss': 0.14854097,
#  'Loss/total_loss': 0.50423896,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.507s
# I0204 12:23:44.682309 8464107584 model_lib_v2.py:705] Step 2100 per-step time 0.507s
# INFO:tensorflow:{'Loss/classification_loss': 0.12079648,
#  'Loss/localization_loss': 0.05673218,
#  'Loss/regularization_loss': 0.14786834,
#  'Loss/total_loss': 0.325397,
#  'learning_rate': 0.07990056}
# I0204 12:23:44.682576 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12079648,
#  'Loss/localization_loss': 0.05673218,
#  'Loss/regularization_loss': 0.14786834,
#  'Loss/total_loss': 0.325397,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.623s
# I0204 12:24:47.018363 8464107584 model_lib_v2.py:705] Step 2200 per-step time 0.623s
# INFO:tensorflow:{'Loss/classification_loss': 0.091457784,
#  'Loss/localization_loss': 0.035537116,
#  'Loss/regularization_loss': 0.1471696,
#  'Loss/total_loss': 0.2741645,
#  'learning_rate': 0.07988167}
# I0204 12:24:47.019436 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.091457784,
#  'Loss/localization_loss': 0.035537116,
#  'Loss/regularization_loss': 0.1471696,
#  'Loss/total_loss': 0.2741645,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.541s
# I0204 12:25:41.134346 8464107584 model_lib_v2.py:705] Step 2300 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.1496116,
#  'Loss/localization_loss': 0.063924395,
#  'Loss/regularization_loss': 0.14650165,
#  'Loss/total_loss': 0.36003762,
#  'learning_rate': 0.07986114}
# I0204 12:25:41.135581 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.1496116,
#  'Loss/localization_loss': 0.063924395,
#  'Loss/regularization_loss': 0.14650165,
#  'Loss/total_loss': 0.36003762,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.564s
# I0204 12:26:37.583789 8464107584 model_lib_v2.py:705] Step 2400 per-step time 0.564s
# INFO:tensorflow:{'Loss/classification_loss': 0.16295803,
#  'Loss/localization_loss': 0.05669787,
#  'Loss/regularization_loss': 0.14582871,
#  'Loss/total_loss': 0.3654846,
#  'learning_rate': 0.07983897}
# I0204 12:26:37.584897 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.16295803,
#  'Loss/localization_loss': 0.05669787,
#  'Loss/regularization_loss': 0.14582871,
#  'Loss/total_loss': 0.3654846,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.533s
# I0204 12:27:30.915585 8464107584 model_lib_v2.py:705] Step 2500 per-step time 0.533s
# INFO:tensorflow:{'Loss/classification_loss': 0.0984505,
#  'Loss/localization_loss': 0.040906027,
#  'Loss/regularization_loss': 0.14527962,
#  'Loss/total_loss': 0.28463614,
#  'learning_rate': 0.079815164}
# I0204 12:27:30.916584 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0984505,
#  'Loss/localization_loss': 0.040906027,
#  'Loss/regularization_loss': 0.14527962,
#  'Loss/total_loss': 0.28463614,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.485s
# I0204 12:28:19.417913 8464107584 model_lib_v2.py:705] Step 2600 per-step time 0.485s
# INFO:tensorflow:{'Loss/classification_loss': 0.12173383,
#  'Loss/localization_loss': 0.039731704,
#  'Loss/regularization_loss': 0.14459576,
#  'Loss/total_loss': 0.30606127,
#  'learning_rate': 0.07978972}
# I0204 12:28:19.418154 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12173383,
#  'Loss/localization_loss': 0.039731704,
#  'Loss/regularization_loss': 0.14459576,
#  'Loss/total_loss': 0.30606127,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.478s
# I0204 12:29:07.189790 8464107584 model_lib_v2.py:705] Step 2700 per-step time 0.478s
# INFO:tensorflow:{'Loss/classification_loss': 0.1138739,
#  'Loss/localization_loss': 0.04742813,
#  'Loss/regularization_loss': 0.14392292,
#  'Loss/total_loss': 0.30522496,
#  'learning_rate': 0.07976264}
# I0204 12:29:07.190819 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.1138739,
#  'Loss/localization_loss': 0.04742813,
#  'Loss/regularization_loss': 0.14392292,
#  'Loss/total_loss': 0.30522496,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.506s
# I0204 12:29:57.771116 8464107584 model_lib_v2.py:705] Step 2800 per-step time 0.506s
# INFO:tensorflow:{'Loss/classification_loss': 0.06330559,
#  'Loss/localization_loss': 0.027472686,
#  'Loss/regularization_loss': 0.14319284,
#  'Loss/total_loss': 0.23397112,
#  'learning_rate': 0.07973392}
# I0204 12:29:57.772104 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06330559,
#  'Loss/localization_loss': 0.027472686,
#  'Loss/regularization_loss': 0.14319284,
#  'Loss/total_loss': 0.23397112,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.479s
# I0204 12:30:45.713581 8464107584 model_lib_v2.py:705] Step 2900 per-step time 0.479s
# INFO:tensorflow:{'Loss/classification_loss': 0.09350367,
#  'Loss/localization_loss': 0.050190948,
#  'Loss/regularization_loss': 0.14250149,
#  'Loss/total_loss': 0.2861961,
#  'learning_rate': 0.07970358}
# I0204 12:30:45.713819 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.09350367,
#  'Loss/localization_loss': 0.050190948,
#  'Loss/regularization_loss': 0.14250149,
#  'Loss/total_loss': 0.2861961,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.481s
# I0204 12:31:33.822747 8464107584 model_lib_v2.py:705] Step 3000 per-step time 0.481s
# INFO:tensorflow:{'Loss/classification_loss': 0.09258257,
#  'Loss/localization_loss': 0.024281831,
#  'Loss/regularization_loss': 0.14180058,
#  'Loss/total_loss': 0.25866497,
#  'learning_rate': 0.0796716}
# I0204 12:31:33.823735 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.09258257,
#  'Loss/localization_loss': 0.024281831,
#  'Loss/regularization_loss': 0.14180058,
#  'Loss/total_loss': 0.25866497,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.530s
# I0204 12:32:26.848069 8464107584 model_lib_v2.py:705] Step 3100 per-step time 0.530s
# INFO:tensorflow:{'Loss/classification_loss': 0.17696315,
#  'Loss/localization_loss': 0.04403494,
#  'Loss/regularization_loss': 0.14110813,
#  'Loss/total_loss': 0.3621062,
#  'learning_rate': 0.07963799}
# I0204 12:32:26.849121 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.17696315,
#  'Loss/localization_loss': 0.04403494,
#  'Loss/regularization_loss': 0.14110813,
#  'Loss/total_loss': 0.3621062,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.572s
# I0204 12:33:24.001152 8464107584 model_lib_v2.py:705] Step 3200 per-step time 0.572s
# INFO:tensorflow:{'Loss/classification_loss': 0.06342416,
#  'Loss/localization_loss': 0.04346564,
#  'Loss/regularization_loss': 0.14040177,
#  'Loss/total_loss': 0.24729156,
#  'learning_rate': 0.07960275}
# I0204 12:33:24.002072 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06342416,
#  'Loss/localization_loss': 0.04346564,
#  'Loss/regularization_loss': 0.14040177,
#  'Loss/total_loss': 0.24729156,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.607s
# I0204 12:34:24.699823 8464107584 model_lib_v2.py:705] Step 3300 per-step time 0.607s
# INFO:tensorflow:{'Loss/classification_loss': 0.08725943,
#  'Loss/localization_loss': 0.022303522,
#  'Loss/regularization_loss': 0.13967746,
#  'Loss/total_loss': 0.24924041,
#  'learning_rate': 0.07956588}
# I0204 12:34:24.700826 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08725943,
#  'Loss/localization_loss': 0.022303522,
#  'Loss/regularization_loss': 0.13967746,
#  'Loss/total_loss': 0.24924041,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.544s
# I0204 12:35:19.127890 8464107584 model_lib_v2.py:705] Step 3400 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.099321,
#  'Loss/localization_loss': 0.032298397,
#  'Loss/regularization_loss': 0.13902135,
#  'Loss/total_loss': 0.27064076,
#  'learning_rate': 0.079527386}
# I0204 12:35:19.128813 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.099321,
#  'Loss/localization_loss': 0.032298397,
#  'Loss/regularization_loss': 0.13902135,
#  'Loss/total_loss': 0.27064076,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.452s
# I0204 12:36:04.308174 8464107584 model_lib_v2.py:705] Step 3500 per-step time 0.452s
# INFO:tensorflow:{'Loss/classification_loss': 0.10922715,
#  'Loss/localization_loss': 0.04711304,
#  'Loss/regularization_loss': 0.13832445,
#  'Loss/total_loss': 0.29466465,
#  'learning_rate': 0.07948727}
# I0204 12:36:04.308376 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10922715,
#  'Loss/localization_loss': 0.04711304,
#  'Loss/regularization_loss': 0.13832445,
#  'Loss/total_loss': 0.29466465,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.443s
# I0204 12:36:48.646582 8464107584 model_lib_v2.py:705] Step 3600 per-step time 0.443s
# INFO:tensorflow:{'Loss/classification_loss': 0.09411382,
#  'Loss/localization_loss': 0.044576384,
#  'Loss/regularization_loss': 0.13769968,
#  'Loss/total_loss': 0.27638987,
#  'learning_rate': 0.079445526}
# I0204 12:36:48.646818 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.09411382,
#  'Loss/localization_loss': 0.044576384,
#  'Loss/regularization_loss': 0.13769968,
#  'Loss/total_loss': 0.27638987,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.423s
# I0204 12:37:30.962384 8464107584 model_lib_v2.py:705] Step 3700 per-step time 0.423s
# INFO:tensorflow:{'Loss/classification_loss': 0.08895041,
#  'Loss/localization_loss': 0.024995644,
#  'Loss/regularization_loss': 0.13700612,
#  'Loss/total_loss': 0.25095218,
#  'learning_rate': 0.07940216}
# I0204 12:37:30.963165 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08895041,
#  'Loss/localization_loss': 0.024995644,
#  'Loss/regularization_loss': 0.13700612,
#  'Loss/total_loss': 0.25095218,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.414s
# I0204 12:38:12.366456 8464107584 model_lib_v2.py:705] Step 3800 per-step time 0.414s
# INFO:tensorflow:{'Loss/classification_loss': 0.06998431,
#  'Loss/localization_loss': 0.040454604,
#  'Loss/regularization_loss': 0.13638397,
#  'Loss/total_loss': 0.2468229,
#  'learning_rate': 0.079357184}
# I0204 12:38:12.366641 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06998431,
#  'Loss/localization_loss': 0.040454604,
#  'Loss/regularization_loss': 0.13638397,
#  'Loss/total_loss': 0.2468229,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.409s
# I0204 12:38:53.246190 8464107584 model_lib_v2.py:705] Step 3900 per-step time 0.409s
# INFO:tensorflow:{'Loss/classification_loss': 0.10924743,
#  'Loss/localization_loss': 0.061770514,
#  'Loss/regularization_loss': 0.13573086,
#  'Loss/total_loss': 0.3067488,
#  'learning_rate': 0.07931058}
# I0204 12:38:53.246366 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10924743,
#  'Loss/localization_loss': 0.061770514,
#  'Loss/regularization_loss': 0.13573086,
#  'Loss/total_loss': 0.3067488,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.521s
# I0204 12:39:45.402768 8464107584 model_lib_v2.py:705] Step 4000 per-step time 0.521s
# INFO:tensorflow:{'Loss/classification_loss': 0.11885066,
#  'Loss/localization_loss': 0.02997225,
#  'Loss/regularization_loss': 0.13510378,
#  'Loss/total_loss': 0.2839267,
#  'learning_rate': 0.07926236}
# I0204 12:39:45.404000 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11885066,
#  'Loss/localization_loss': 0.02997225,
#  'Loss/regularization_loss': 0.13510378,
#  'Loss/total_loss': 0.2839267,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.397s
# I0204 12:40:25.138415 8464107584 model_lib_v2.py:705] Step 4100 per-step time 0.397s
# INFO:tensorflow:{'Loss/classification_loss': 0.11994747,
#  'Loss/localization_loss': 0.08877764,
#  'Loss/regularization_loss': 0.13442637,
#  'Loss/total_loss': 0.34315148,
#  'learning_rate': 0.07921253}
# I0204 12:40:25.138595 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11994747,
#  'Loss/localization_loss': 0.08877764,
#  'Loss/regularization_loss': 0.13442637,
#  'Loss/total_loss': 0.34315148,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.408s
# I0204 12:41:05.922806 8464107584 model_lib_v2.py:705] Step 4200 per-step time 0.408s
# INFO:tensorflow:{'Loss/classification_loss': 0.07916735,
#  'Loss/localization_loss': 0.036419004,
#  'Loss/regularization_loss': 0.13378638,
#  'Loss/total_loss': 0.24937274,
#  'learning_rate': 0.07916109}
# I0204 12:41:05.922981 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07916735,
#  'Loss/localization_loss': 0.036419004,
#  'Loss/regularization_loss': 0.13378638,
#  'Loss/total_loss': 0.24937274,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.396s
# I0204 12:41:45.510046 8464107584 model_lib_v2.py:705] Step 4300 per-step time 0.396s
# INFO:tensorflow:{'Loss/classification_loss': 0.12452673,
#  'Loss/localization_loss': 0.019676937,
#  'Loss/regularization_loss': 0.13309312,
#  'Loss/total_loss': 0.27729678,
#  'learning_rate': 0.07910804}
# I0204 12:41:45.510217 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12452673,
#  'Loss/localization_loss': 0.019676937,
#  'Loss/regularization_loss': 0.13309312,
#  'Loss/total_loss': 0.27729678,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.401s
# I0204 12:42:25.597445 8464107584 model_lib_v2.py:705] Step 4400 per-step time 0.401s
# INFO:tensorflow:{'Loss/classification_loss': 0.12058113,
#  'Loss/localization_loss': 0.0338013,
#  'Loss/regularization_loss': 0.13243555,
#  'Loss/total_loss': 0.28681797,
#  'learning_rate': 0.07905338}
# I0204 12:42:25.597635 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12058113,
#  'Loss/localization_loss': 0.0338013,
#  'Loss/regularization_loss': 0.13243555,
#  'Loss/total_loss': 0.28681797,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.393s
# I0204 12:43:04.945555 8464107584 model_lib_v2.py:705] Step 4500 per-step time 0.393s
# INFO:tensorflow:{'Loss/classification_loss': 0.08741885,
#  'Loss/localization_loss': 0.025151063,
#  'Loss/regularization_loss': 0.131752,
#  'Loss/total_loss': 0.2443219,
#  'learning_rate': 0.07899711}
# I0204 12:43:04.945729 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08741885,
#  'Loss/localization_loss': 0.025151063,
#  'Loss/regularization_loss': 0.131752,
#  'Loss/total_loss': 0.2443219,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.447s
# I0204 12:43:49.610386 8464107584 model_lib_v2.py:705] Step 4600 per-step time 0.447s
# INFO:tensorflow:{'Loss/classification_loss': 0.08033131,
#  'Loss/localization_loss': 0.017966969,
#  'Loss/regularization_loss': 0.13106927,
#  'Loss/total_loss': 0.22936755,
#  'learning_rate': 0.078939244}
# I0204 12:43:49.611129 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08033131,
#  'Loss/localization_loss': 0.017966969,
#  'Loss/regularization_loss': 0.13106927,
#  'Loss/total_loss': 0.22936755,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.402s
# I0204 12:44:29.844949 8464107584 model_lib_v2.py:705] Step 4700 per-step time 0.402s
# INFO:tensorflow:{'Loss/classification_loss': 0.06459725,
#  'Loss/localization_loss': 0.014125631,
#  'Loss/regularization_loss': 0.130387,
#  'Loss/total_loss': 0.20910987,
#  'learning_rate': 0.07887978}
# I0204 12:44:29.845144 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06459725,
#  'Loss/localization_loss': 0.014125631,
#  'Loss/regularization_loss': 0.130387,
#  'Loss/total_loss': 0.20910987,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.401s
# I0204 12:45:09.902970 8464107584 model_lib_v2.py:705] Step 4800 per-step time 0.401s
# INFO:tensorflow:{'Loss/classification_loss': 0.08205184,
#  'Loss/localization_loss': 0.020980552,
#  'Loss/regularization_loss': 0.12976725,
#  'Loss/total_loss': 0.23279965,
#  'learning_rate': 0.07881871}
# I0204 12:45:09.903174 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08205184,
#  'Loss/localization_loss': 0.020980552,
#  'Loss/regularization_loss': 0.12976725,
#  'Loss/total_loss': 0.23279965,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.446s
# I0204 12:45:54.456241 8464107584 model_lib_v2.py:705] Step 4900 per-step time 0.446s
# INFO:tensorflow:{'Loss/classification_loss': 0.07348177,
#  'Loss/localization_loss': 0.022609942,
#  'Loss/regularization_loss': 0.12913652,
#  'Loss/total_loss': 0.22522822,
#  'learning_rate': 0.07875605}
# I0204 12:45:54.456554 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07348177,
#  'Loss/localization_loss': 0.022609942,
#  'Loss/regularization_loss': 0.12913652,
#  'Loss/total_loss': 0.22522822,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.401s
# I0204 12:46:34.572802 8464107584 model_lib_v2.py:705] Step 5000 per-step time 0.401s
# INFO:tensorflow:{'Loss/classification_loss': 0.08035925,
#  'Loss/localization_loss': 0.041951012,
#  'Loss/regularization_loss': 0.12845331,
#  'Loss/total_loss': 0.2507636,
#  'learning_rate': 0.078691795}
# I0204 12:46:34.572992 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08035925,
#  'Loss/localization_loss': 0.041951012,
#  'Loss/regularization_loss': 0.12845331,
#  'Loss/total_loss': 0.2507636,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.412s
# I0204 12:47:15.809093 8464107584 model_lib_v2.py:705] Step 5100 per-step time 0.412s
# INFO:tensorflow:{'Loss/classification_loss': 0.061176967,
#  'Loss/localization_loss': 0.038672347,
#  'Loss/regularization_loss': 0.12808694,
#  'Loss/total_loss': 0.22793625,
#  'learning_rate': 0.07862595}
# I0204 12:47:15.809342 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.061176967,
#  'Loss/localization_loss': 0.038672347,
#  'Loss/regularization_loss': 0.12808694,
#  'Loss/total_loss': 0.22793625,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.469s
# I0204 12:48:02.717391 8464107584 model_lib_v2.py:705] Step 5200 per-step time 0.469s
# INFO:tensorflow:{'Loss/classification_loss': 0.18327338,
#  'Loss/localization_loss': 0.044409256,
#  'Loss/regularization_loss': 0.12841044,
#  'Loss/total_loss': 0.35609308,
#  'learning_rate': 0.07855851}
# I0204 12:48:02.717581 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.18327338,
#  'Loss/localization_loss': 0.044409256,
#  'Loss/regularization_loss': 0.12841044,
#  'Loss/total_loss': 0.35609308,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.401s
# I0204 12:48:42.789142 8464107584 model_lib_v2.py:705] Step 5300 per-step time 0.401s
# INFO:tensorflow:{'Loss/classification_loss': 0.08574019,
#  'Loss/localization_loss': 0.028532442,
#  'Loss/regularization_loss': 0.12785418,
#  'Loss/total_loss': 0.24212682,
#  'learning_rate': 0.07848949}
# I0204 12:48:42.789330 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08574019,
#  'Loss/localization_loss': 0.028532442,
#  'Loss/regularization_loss': 0.12785418,
#  'Loss/total_loss': 0.24212682,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.422s
# I0204 12:49:25.017495 8464107584 model_lib_v2.py:705] Step 5400 per-step time 0.422s
# INFO:tensorflow:{'Loss/classification_loss': 0.059119947,
#  'Loss/localization_loss': 0.03199847,
#  'Loss/regularization_loss': 0.12724014,
#  'Loss/total_loss': 0.21835855,
#  'learning_rate': 0.078418896}
# I0204 12:49:25.017669 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.059119947,
#  'Loss/localization_loss': 0.03199847,
#  'Loss/regularization_loss': 0.12724014,
#  'Loss/total_loss': 0.21835855,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.404s
# I0204 12:50:05.392915 8464107584 model_lib_v2.py:705] Step 5500 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.08204542,
#  'Loss/localization_loss': 0.013503234,
#  'Loss/regularization_loss': 0.12658897,
#  'Loss/total_loss': 0.22213763,
#  'learning_rate': 0.078346714}
# I0204 12:50:05.393086 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08204542,
#  'Loss/localization_loss': 0.013503234,
#  'Loss/regularization_loss': 0.12658897,
#  'Loss/total_loss': 0.22213763,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.383s
# I0204 12:50:43.729401 8464107584 model_lib_v2.py:705] Step 5600 per-step time 0.383s
# INFO:tensorflow:{'Loss/classification_loss': 0.11126741,
#  'Loss/localization_loss': 0.020458458,
#  'Loss/regularization_loss': 0.12595493,
#  'Loss/total_loss': 0.2576808,
#  'learning_rate': 0.07827295}
# I0204 12:50:43.729578 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11126741,
#  'Loss/localization_loss': 0.020458458,
#  'Loss/regularization_loss': 0.12595493,
#  'Loss/total_loss': 0.2576808,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.437s
# I0204 12:51:27.392581 8464107584 model_lib_v2.py:705] Step 5700 per-step time 0.437s
# INFO:tensorflow:{'Loss/classification_loss': 0.10539733,
#  'Loss/localization_loss': 0.035229556,
#  'Loss/regularization_loss': 0.12531015,
#  'Loss/total_loss': 0.26593703,
#  'learning_rate': 0.07819763}
# I0204 12:51:27.393236 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10539733,
#  'Loss/localization_loss': 0.035229556,
#  'Loss/regularization_loss': 0.12531015,
#  'Loss/total_loss': 0.26593703,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.399s
# I0204 12:52:07.322615 8464107584 model_lib_v2.py:705] Step 5800 per-step time 0.399s
# INFO:tensorflow:{'Loss/classification_loss': 0.06794226,
#  'Loss/localization_loss': 0.025744278,
#  'Loss/regularization_loss': 0.12468075,
#  'Loss/total_loss': 0.2183673,
#  'learning_rate': 0.07812072}
# I0204 12:52:07.322813 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06794226,
#  'Loss/localization_loss': 0.025744278,
#  'Loss/regularization_loss': 0.12468075,
#  'Loss/total_loss': 0.2183673,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.384s
# I0204 12:52:45.769795 8464107584 model_lib_v2.py:705] Step 5900 per-step time 0.384s
# INFO:tensorflow:{'Loss/classification_loss': 0.069242746,
#  'Loss/localization_loss': 0.012182509,
#  'Loss/regularization_loss': 0.12408813,
#  'Loss/total_loss': 0.20551339,
#  'learning_rate': 0.078042254}
# I0204 12:52:45.770042 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.069242746,
#  'Loss/localization_loss': 0.012182509,
#  'Loss/regularization_loss': 0.12408813,
#  'Loss/total_loss': 0.20551339,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.412s
# I0204 12:53:26.935396 8464107584 model_lib_v2.py:705] Step 6000 per-step time 0.412s
# INFO:tensorflow:{'Loss/classification_loss': 0.06368214,
#  'Loss/localization_loss': 0.020227455,
#  'Loss/regularization_loss': 0.12349168,
#  'Loss/total_loss': 0.20740128,
#  'learning_rate': 0.07796223}
# I0204 12:53:26.935577 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06368214,
#  'Loss/localization_loss': 0.020227455,
#  'Loss/regularization_loss': 0.12349168,
#  'Loss/total_loss': 0.20740128,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.460s
# I0204 12:54:12.944735 8464107584 model_lib_v2.py:705] Step 6100 per-step time 0.460s
# INFO:tensorflow:{'Loss/classification_loss': 0.06881502,
#  'Loss/localization_loss': 0.02875336,
#  'Loss/regularization_loss': 0.12287779,
#  'Loss/total_loss': 0.22044617,
#  'learning_rate': 0.077880636}
# I0204 12:54:12.945101 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06881502,
#  'Loss/localization_loss': 0.02875336,
#  'Loss/regularization_loss': 0.12287779,
#  'Loss/total_loss': 0.22044617,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.472s
# I0204 12:55:00.110371 8464107584 model_lib_v2.py:705] Step 6200 per-step time 0.472s
# INFO:tensorflow:{'Loss/classification_loss': 0.13165882,
#  'Loss/localization_loss': 0.022805534,
#  'Loss/regularization_loss': 0.12225875,
#  'Loss/total_loss': 0.27672312,
#  'learning_rate': 0.07779749}
# I0204 12:55:00.111212 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.13165882,
#  'Loss/localization_loss': 0.022805534,
#  'Loss/regularization_loss': 0.12225875,
#  'Loss/total_loss': 0.27672312,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 0.457s
# I0204 12:55:45.848507 8464107584 model_lib_v2.py:705] Step 6300 per-step time 0.457s
# INFO:tensorflow:{'Loss/classification_loss': 0.055626016,
#  'Loss/localization_loss': 0.019548455,
#  'Loss/regularization_loss': 0.1216639,
#  'Loss/total_loss': 0.19683838,
#  'learning_rate': 0.07771279}
# I0204 12:55:45.848933 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.055626016,
#  'Loss/localization_loss': 0.019548455,
#  'Loss/regularization_loss': 0.1216639,
#  'Loss/total_loss': 0.19683838,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.458s
# I0204 12:56:31.601963 8464107584 model_lib_v2.py:705] Step 6400 per-step time 0.458s
# INFO:tensorflow:{'Loss/classification_loss': 0.068301626,
#  'Loss/localization_loss': 0.058932025,
#  'Loss/regularization_loss': 0.12107572,
#  'Loss/total_loss': 0.24830937,
#  'learning_rate': 0.077626534}
# I0204 12:56:31.602332 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.068301626,
#  'Loss/localization_loss': 0.058932025,
#  'Loss/regularization_loss': 0.12107572,
#  'Loss/total_loss': 0.24830937,
#  'learning_rate': 0.077626534}
# INFO:tensorflow:Step 6500 per-step time 0.469s
# I0204 12:57:18.509006 8464107584 model_lib_v2.py:705] Step 6500 per-step time 0.469s
# INFO:tensorflow:{'Loss/classification_loss': 0.08758253,
#  'Loss/localization_loss': 0.020732008,
#  'Loss/regularization_loss': 0.12047085,
#  'Loss/total_loss': 0.2287854,
#  'learning_rate': 0.077538736}
# I0204 12:57:18.509786 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08758253,
#  'Loss/localization_loss': 0.020732008,
#  'Loss/regularization_loss': 0.12047085,
#  'Loss/total_loss': 0.2287854,
#  'learning_rate': 0.077538736}
# INFO:tensorflow:Step 6600 per-step time 0.459s
# I0204 12:58:04.358911 8464107584 model_lib_v2.py:705] Step 6600 per-step time 0.459s
# INFO:tensorflow:{'Loss/classification_loss': 0.06976365,
#  'Loss/localization_loss': 0.03459198,
#  'Loss/regularization_loss': 0.11988964,
#  'Loss/total_loss': 0.22424528,
#  'learning_rate': 0.07744939}
# I0204 12:58:04.359194 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06976365,
#  'Loss/localization_loss': 0.03459198,
#  'Loss/regularization_loss': 0.11988964,
#  'Loss/total_loss': 0.22424528,
#  'learning_rate': 0.07744939}
# INFO:tensorflow:Step 6700 per-step time 0.451s
# I0204 12:58:49.451189 8464107584 model_lib_v2.py:705] Step 6700 per-step time 0.451s
# INFO:tensorflow:{'Loss/classification_loss': 0.06521906,
#  'Loss/localization_loss': 0.021851659,
#  'Loss/regularization_loss': 0.11927487,
#  'Loss/total_loss': 0.20634559,
#  'learning_rate': 0.077358514}
# I0204 12:58:49.451398 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06521906,
#  'Loss/localization_loss': 0.021851659,
#  'Loss/regularization_loss': 0.11927487,
#  'Loss/total_loss': 0.20634559,
#  'learning_rate': 0.077358514}
# INFO:tensorflow:Step 6800 per-step time 0.437s
# I0204 12:59:33.141997 8464107584 model_lib_v2.py:705] Step 6800 per-step time 0.437s
# INFO:tensorflow:{'Loss/classification_loss': 0.046998437,
#  'Loss/localization_loss': 0.023158165,
#  'Loss/regularization_loss': 0.11869943,
#  'Loss/total_loss': 0.18885604,
#  'learning_rate': 0.0772661}
# I0204 12:59:33.142240 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.046998437,
#  'Loss/localization_loss': 0.023158165,
#  'Loss/regularization_loss': 0.11869943,
#  'Loss/total_loss': 0.18885604,
#  'learning_rate': 0.0772661}
# INFO:tensorflow:Step 6900 per-step time 0.510s
# I0204 13:00:24.189466 8464107584 model_lib_v2.py:705] Step 6900 per-step time 0.510s
# INFO:tensorflow:{'Loss/classification_loss': 0.054908633,
# ...
# INFO:tensorflow:Step 7300 per-step time 0.476s
# I0204 13:03:29.749490 8464107584 model_lib_v2.py:705] Step 7300 per-step time 0.476s
# INFO:tensorflow:{'Loss/classification_loss': 0.10023002,
#  'Loss/localization_loss': 0.021821827,
#  'Loss/regularization_loss': 0.115858994,
#  'Loss/total_loss': 0.23791085,
#  'learning_rate': 0.07678111}
# I0204 13:03:29.749794 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10023002,
#  'Loss/localization_loss': 0.021821827,
#  'Loss/regularization_loss': 0.115858994,
#  'Loss/total_loss': 0.23791085,
#  'learning_rate': 0.07678111}
# INFO:tensorflow:Step 7400 per-step time 0.469s
# I0204 13:04:16.630670 8464107584 model_lib_v2.py:705] Step 7400 per-step time 0.469s
# INFO:tensorflow:{'Loss/classification_loss': 0.058102548,
#  'Loss/localization_loss': 0.01957653,
#  'Loss/regularization_loss': 0.11533342,
#  'Loss/total_loss': 0.1930125,
#  'learning_rate': 0.076679565}
# I0204 13:04:16.631677 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.058102548,
#  'Loss/localization_loss': 0.01957653,
#  'Loss/regularization_loss': 0.11533342,
#  'Loss/total_loss': 0.1930125,
#  'learning_rate': 0.076679565}
# INFO:tensorflow:Step 7500 per-step time 0.498s
# I0204 13:05:06.460253 8464107584 model_lib_v2.py:705] Step 7500 per-step time 0.498s
# INFO:tensorflow:{'Loss/classification_loss': 0.08795368,
#  'Loss/localization_loss': 0.042064413,
#  'Loss/regularization_loss': 0.1147466,
#  'Loss/total_loss': 0.24476469,
#  'learning_rate': 0.0765765}
# I0204 13:05:06.460644 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08795368,
#  'Loss/localization_loss': 0.042064413,
#  'Loss/regularization_loss': 0.1147466,
#  'Loss/total_loss': 0.24476469,
#  'learning_rate': 0.0765765}
# INFO:tensorflow:Step 7600 per-step time 0.511s
# I0204 13:05:57.625029 8464107584 model_lib_v2.py:705] Step 7600 per-step time 0.511s
# INFO:tensorflow:{'Loss/classification_loss': 0.081448704,
#  'Loss/localization_loss': 0.029715238,
#  'Loss/regularization_loss': 0.11417843,
#  'Loss/total_loss': 0.22534236,
#  'learning_rate': 0.07647194}
# I0204 13:05:57.625694 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.081448704,
#  'Loss/localization_loss': 0.029715238,
#  'Loss/regularization_loss': 0.11417843,
#  'Loss/total_loss': 0.22534236,
#  'learning_rate': 0.07647194}
# INFO:tensorflow:Step 7700 per-step time 0.573s
# I0204 13:06:54.872939 8464107584 model_lib_v2.py:705] Step 7700 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.04047207,
#  'Loss/localization_loss': 0.017546102,
#  'Loss/regularization_loss': 0.113601655,
#  'Loss/total_loss': 0.17161983,
#  'learning_rate': 0.07636588}
# I0204 13:06:54.873995 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.04047207,
#  'Loss/localization_loss': 0.017546102,
#  'Loss/regularization_loss': 0.113601655,
#  'Loss/total_loss': 0.17161983,
#  'learning_rate': 0.07636588}
# INFO:tensorflow:Step 7800 per-step time 0.560s
# I0204 13:07:50.873039 8464107584 model_lib_v2.py:705] Step 7800 per-step time 0.560s
# INFO:tensorflow:{'Loss/classification_loss': 0.07833705,
#  'Loss/localization_loss': 0.0420869,
#  'Loss/regularization_loss': 0.113068774,
#  'Loss/total_loss': 0.23349273,
#  'learning_rate': 0.07625833}
# I0204 13:07:50.874010 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07833705,
#  'Loss/localization_loss': 0.0420869,
#  'Loss/regularization_loss': 0.113068774,
#  'Loss/total_loss': 0.23349273,
#  'learning_rate': 0.07625833}
# INFO:tensorflow:Step 7900 per-step time 0.561s
# I0204 13:08:46.947158 8464107584 model_lib_v2.py:705] Step 7900 per-step time 0.561s
# INFO:tensorflow:{'Loss/classification_loss': 0.05985976,
#  'Loss/localization_loss': 0.019861398,
#  'Loss/regularization_loss': 0.11251162,
#  'Loss/total_loss': 0.19223279,
#  'learning_rate': 0.07614928}
# I0204 13:08:46.947808 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.05985976,
#  'Loss/localization_loss': 0.019861398,
#  'Loss/regularization_loss': 0.11251162,
#  'Loss/total_loss': 0.19223279,
#  'learning_rate': 0.07614928}
# INFO:tensorflow:Step 8000 per-step time 0.511s
# I0204 13:09:38.063088 8464107584 model_lib_v2.py:705] Step 8000 per-step time 0.511s
# INFO:tensorflow:{'Loss/classification_loss': 0.06840619,
#  'Loss/localization_loss': 0.019092409,
#  'Loss/regularization_loss': 0.11196449,
#  'Loss/total_loss': 0.19946308,
#  'learning_rate': 0.07603875}
# I0204 13:09:38.063334 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06840619,
#  'Loss/localization_loss': 0.019092409,
#  'Loss/regularization_loss': 0.11196449,
#  'Loss/total_loss': 0.19946308,
#  'learning_rate': 0.07603875}
# INFO:tensorflow:Step 8100 per-step time 0.506s
# I0204 13:10:28.706241 8464107584 model_lib_v2.py:705] Step 8100 per-step time 0.506s
# INFO:tensorflow:{'Loss/classification_loss': 0.0610209,
#  'Loss/localization_loss': 0.014076622,
#  'Loss/regularization_loss': 0.11145476,
#  'Loss/total_loss': 0.18655229,
#  'learning_rate': 0.07592674}
# I0204 13:10:28.706666 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0610209,
#  'Loss/localization_loss': 0.014076622,
#  'Loss/regularization_loss': 0.11145476,
#  'Loss/total_loss': 0.18655229,
#  'learning_rate': 0.07592674}
# INFO:tensorflow:Step 8200 per-step time 0.516s
# I0204 13:11:20.349874 8464107584 model_lib_v2.py:705] Step 8200 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.041319992,
#  'Loss/localization_loss': 0.00866202,
#  'Loss/regularization_loss': 0.110894024,
#  'Loss/total_loss': 0.16087604,
#  'learning_rate': 0.075813256}
# I0204 13:11:20.350157 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.041319992,
#  'Loss/localization_loss': 0.00866202,
#  'Loss/regularization_loss': 0.110894024,
#  'Loss/total_loss': 0.16087604,
#  'learning_rate': 0.075813256}
# INFO:tensorflow:Step 8300 per-step time 0.512s
# I0204 13:12:11.571183 8464107584 model_lib_v2.py:705] Step 8300 per-step time 0.512s
# INFO:tensorflow:{'Loss/classification_loss': 0.054903254,
#  'Loss/localization_loss': 0.013526025,
#  'Loss/regularization_loss': 0.110340275,
#  'Loss/total_loss': 0.17876956,
#  'learning_rate': 0.07569829}
# I0204 13:12:11.571503 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.054903254,
#  'Loss/localization_loss': 0.013526025,
#  'Loss/regularization_loss': 0.110340275,
#  'Loss/total_loss': 0.17876956,
#  'learning_rate': 0.07569829}
# INFO:tensorflow:Step 8400 per-step time 0.485s
# I0204 13:13:00.028745 8464107584 model_lib_v2.py:705] Step 8400 per-step time 0.485s
# INFO:tensorflow:{'Loss/classification_loss': 0.051208228,
#  'Loss/localization_loss': 0.017847119,
#  'Loss/regularization_loss': 0.10980686,
#  'Loss/total_loss': 0.1788622,
#  'learning_rate': 0.07558186}
# I0204 13:13:00.028984 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.051208228,
#  'Loss/localization_loss': 0.017847119,
#  'Loss/regularization_loss': 0.10980686,
#  'Loss/total_loss': 0.1788622,
#  'learning_rate': 0.07558186}
# INFO:tensorflow:Step 8500 per-step time 0.468s
# I0204 13:13:46.874117 8464107584 model_lib_v2.py:705] Step 8500 per-step time 0.468s
# INFO:tensorflow:{'Loss/classification_loss': 0.1074465,
#  'Loss/localization_loss': 0.020143894,
#  'Loss/regularization_loss': 0.10930376,
#  'Loss/total_loss': 0.23689416,
#  'learning_rate': 0.07546397}
# I0204 13:13:46.874343 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.1074465,
#  'Loss/localization_loss': 0.020143894,
#  'Loss/regularization_loss': 0.10930376,
#  'Loss/total_loss': 0.23689416,
#  'learning_rate': 0.07546397}
# INFO:tensorflow:Step 8600 per-step time 0.471s
# I0204 13:14:33.922260 8464107584 model_lib_v2.py:705] Step 8600 per-step time 0.471s
# INFO:tensorflow:{'Loss/classification_loss': 0.07034705,
#  'Loss/localization_loss': 0.022785626,
#  'Loss/regularization_loss': 0.10878346,
#  'Loss/total_loss': 0.20191613,
#  'learning_rate': 0.075344615}
# I0204 13:14:33.922653 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07034705,
#  'Loss/localization_loss': 0.022785626,
#  'Loss/regularization_loss': 0.10878346,
#  'Loss/total_loss': 0.20191613,
#  'learning_rate': 0.075344615}
# INFO:tensorflow:Step 8700 per-step time 0.495s
# I0204 13:15:23.389874 8464107584 model_lib_v2.py:705] Step 8700 per-step time 0.495s
# INFO:tensorflow:{'Loss/classification_loss': 0.07252439,
#  'Loss/localization_loss': 0.016195398,
#  'Loss/regularization_loss': 0.1085406,
#  'Loss/total_loss': 0.19726038,
#  'learning_rate': 0.07522382}
# I0204 13:15:23.390108 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07252439,
#  'Loss/localization_loss': 0.016195398,
#  'Loss/regularization_loss': 0.1085406,
#  'Loss/total_loss': 0.19726038,
#  'learning_rate': 0.07522382}
# INFO:tensorflow:Step 8800 per-step time 0.516s
# I0204 13:16:15.023553 8464107584 model_lib_v2.py:705] Step 8800 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.08205269,
#  'Loss/localization_loss': 0.014786098,
#  'Loss/regularization_loss': 0.10804821,
#  'Loss/total_loss': 0.204887,
#  'learning_rate': 0.07510157}
# I0204 13:16:15.023829 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08205269,
#  'Loss/localization_loss': 0.014786098,
#  'Loss/regularization_loss': 0.10804821,
#  'Loss/total_loss': 0.204887,
#  'learning_rate': 0.07510157}
# INFO:tensorflow:Step 8900 per-step time 0.512s
# I0204 13:17:06.229449 8464107584 model_lib_v2.py:705] Step 8900 per-step time 0.512s
# INFO:tensorflow:{'Loss/classification_loss': 0.059107494,
#  'Loss/localization_loss': 0.016874429,
#  'Loss/regularization_loss': 0.10757102,
#  'Loss/total_loss': 0.18355295,
#  'learning_rate': 0.074977875}
# I0204 13:17:06.229806 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.059107494,
#  'Loss/localization_loss': 0.016874429,
#  'Loss/regularization_loss': 0.10757102,
#  'Loss/total_loss': 0.18355295,
#  'learning_rate': 0.074977875}
# INFO:tensorflow:Step 9000 per-step time 0.520s
# I0204 13:17:58.192932 8464107584 model_lib_v2.py:705] Step 9000 per-step time 0.520s
# INFO:tensorflow:{'Loss/classification_loss': 0.0632934,
#  'Loss/localization_loss': 0.022514058,
#  'Loss/regularization_loss': 0.10708716,
#  'Loss/total_loss': 0.19289461,
#  'learning_rate': 0.07485275}
# I0204 13:17:58.193403 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0632934,
#  'Loss/localization_loss': 0.022514058,
#  'Loss/regularization_loss': 0.10708716,
#  'Loss/total_loss': 0.19289461,
#  'learning_rate': 0.07485275}
# INFO:tensorflow:Step 9100 per-step time 0.510s
# I0204 13:18:49.143750 8464107584 model_lib_v2.py:705] Step 9100 per-step time 0.510s
# INFO:tensorflow:{'Loss/classification_loss': 0.046867374,
#  'Loss/localization_loss': 0.014181407,
#  'Loss/regularization_loss': 0.106624685,
#  'Loss/total_loss': 0.16767347,
#  'learning_rate': 0.07472619}
# I0204 13:18:49.144011 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.046867374,
#  'Loss/localization_loss': 0.014181407,
#  'Loss/regularization_loss': 0.106624685,
#  'Loss/total_loss': 0.16767347,
#  'learning_rate': 0.07472619}
# INFO:tensorflow:Step 9200 per-step time 0.503s
# I0204 13:19:39.464350 8464107584 model_lib_v2.py:705] Step 9200 per-step time 0.503s
# INFO:tensorflow:{'Loss/classification_loss': 0.061079673,
#  'Loss/localization_loss': 0.01126455,
#  'Loss/regularization_loss': 0.10612967,
#  'Loss/total_loss': 0.17847389,
#  'learning_rate': 0.07459819}
# I0204 13:19:39.464596 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.061079673,
#  'Loss/localization_loss': 0.01126455,
#  'Loss/regularization_loss': 0.10612967,
#  'Loss/total_loss': 0.17847389,
#  'learning_rate': 0.07459819}
# INFO:tensorflow:Step 9300 per-step time 0.508s
# I0204 13:20:30.229546 8464107584 model_lib_v2.py:705] Step 9300 per-step time 0.508s
# INFO:tensorflow:{'Loss/classification_loss': 0.0981708,
#  'Loss/localization_loss': 0.016754849,
#  'Loss/regularization_loss': 0.10561543,
#  'Loss/total_loss': 0.22054109,
#  'learning_rate': 0.074468784}
# I0204 13:20:30.229770 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.0981708,
#  'Loss/localization_loss': 0.016754849,
#  'Loss/regularization_loss': 0.10561543,
#  'Loss/total_loss': 0.22054109,
#  'learning_rate': 0.074468784}
# INFO:tensorflow:Step 9400 per-step time 0.518s
# I0204 13:21:22.002045 8464107584 model_lib_v2.py:705] Step 9400 per-step time 0.518s
# INFO:tensorflow:{'Loss/classification_loss': 0.057393596,
#  'Loss/localization_loss': 0.018721769,
#  'Loss/regularization_loss': 0.105201766,
#  'Loss/total_loss': 0.18131712,
#  'learning_rate': 0.074337944}
# I0204 13:21:22.002298 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.057393596,
#  'Loss/localization_loss': 0.018721769,
#  'Loss/regularization_loss': 0.105201766,
#  'Loss/total_loss': 0.18131712,
#  'learning_rate': 0.074337944}
# INFO:tensorflow:Step 9500 per-step time 0.516s
# I0204 13:22:13.558878 8464107584 model_lib_v2.py:705] Step 9500 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.075567886,
#  'Loss/localization_loss': 0.019739723,
#  'Loss/regularization_loss': 0.104703106,
#  'Loss/total_loss': 0.20001072,
#  'learning_rate': 0.074205704}
# I0204 13:22:13.559119 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.075567886,
#  'Loss/localization_loss': 0.019739723,
#  'Loss/regularization_loss': 0.104703106,
#  'Loss/total_loss': 0.20001072,
#  'learning_rate': 0.074205704}
# INFO:tensorflow:Step 9600 per-step time 0.513s
# I0204 13:23:04.816123 8464107584 model_lib_v2.py:705] Step 9600 per-step time 0.513s
# INFO:tensorflow:{'Loss/classification_loss': 0.07997705,
#  'Loss/localization_loss': 0.02238386,
#  'Loss/regularization_loss': 0.10421779,
#  'Loss/total_loss': 0.2065787,
#  'learning_rate': 0.07407206}
# I0204 13:23:04.816517 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07997705,
#  'Loss/localization_loss': 0.02238386,
#  'Loss/regularization_loss': 0.10421779,
#  'Loss/total_loss': 0.2065787,
#  'learning_rate': 0.07407206}
# INFO:tensorflow:Step 9700 per-step time 0.507s
# I0204 13:23:55.473973 8464107584 model_lib_v2.py:705] Step 9700 per-step time 0.507s
# INFO:tensorflow:{'Loss/classification_loss': 0.07352801,
#  'Loss/localization_loss': 0.009312519,
#  'Loss/regularization_loss': 0.103714615,
#  'Loss/total_loss': 0.18655515,
#  'learning_rate': 0.073937014}
# I0204 13:23:55.474251 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07352801,
#  'Loss/localization_loss': 0.009312519,
#  'Loss/regularization_loss': 0.103714615,
#  'Loss/total_loss': 0.18655515,
#  'learning_rate': 0.073937014}
# INFO:tensorflow:Step 9800 per-step time 0.507s
# I0204 13:24:46.141234 8464107584 model_lib_v2.py:705] Step 9800 per-step time 0.507s
# INFO:tensorflow:{'Loss/classification_loss': 0.054556873,
#  'Loss/localization_loss': 0.017248457,
#  'Loss/regularization_loss': 0.103244804,
#  'Loss/total_loss': 0.17505014,
#  'learning_rate': 0.07380057}
# I0204 13:24:46.141504 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.054556873,
#  'Loss/localization_loss': 0.017248457,
#  'Loss/regularization_loss': 0.103244804,
#  'Loss/total_loss': 0.17505014,
#  'learning_rate': 0.07380057}
# INFO:tensorflow:Step 9900 per-step time 0.511s
# I0204 13:25:37.227210 8464107584 model_lib_v2.py:705] Step 9900 per-step time 0.511s
# INFO:tensorflow:{'Loss/classification_loss': 0.06773477,
#  'Loss/localization_loss': 0.018535782,
#  'Loss/regularization_loss': 0.10276527,
#  'Loss/total_loss': 0.18903583,
#  'learning_rate': 0.073662736}
# I0204 13:25:37.227488 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06773477,
#  'Loss/localization_loss': 0.018535782,
#  'Loss/regularization_loss': 0.10276527,
#  'Loss/total_loss': 0.18903583,
#  'learning_rate': 0.073662736}
# INFO:tensorflow:Step 10000 per-step time 0.610s
# I0204 13:26:38.288800 8464107584 model_lib_v2.py:705] Step 10000 per-step time 0.610s
# INFO:tensorflow:{'Loss/classification_loss': 0.050908126,
#  'Loss/localization_loss': 0.037377674,
#  'Loss/regularization_loss': 0.102317914,
#  'Loss/total_loss': 0.19060372,
#  'learning_rate': 0.07352352}
# I0204 13:26:38.291866 8464107584 model_lib_v2.py:708] {'Loss/classification_loss': 0.050908126,
#  'Loss/localization_loss': 0.037377674,
#  'Loss/regularization_loss': 0.102317914,
#  'Loss/total_loss': 0.19060372,
#  'learning_rate': 0.07352352}

# %% [markdown]
# # 7. LOAD trained model from checkpoint

# %%
import os
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder

# %% [markdown]
# !! UPDATE .ckpt to latest on in my_ssd_mobnet

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
# UPDATE ckpt-XX to latest checkpoint
ckpt.restore(os.path.join(CHECKPOINT_PATH, 'ckpt-11')).expect_partial() 

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 8 - RTOD pretrained sign language gloss detection

# %%
import cv2
import numpy as np
# added to ensure stream closes properly
import tensorflow as tf
from object_detection.utils import visualization_utils as viz_utils

# %%
category_index = label_map_util.create_category_index_from_labelmap(ANNOTATION_PATH+'/label_map.pbtxt')

# %%
# Setup capture
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
# start webcam and log detected objects with confidence score

import cv2
import numpy as np
import tensorflow as tf
from object_detection.utils import visualization_utils as viz_utils
import time

# Define a function to log detected objects
def log_detected_objects(detections, category_index):
    log = []
    for i in range(detections['num_detections']):
        if detections['detection_scores'][i] >= 0.8:
            class_id = detections['detection_classes'][i]
            if class_id in category_index:
                class_name = category_index[class_id]['name']
                score = detections['detection_scores'][i]
                log.append((class_name, score))
    return log

# Initialize logging list
detected_objects_log = []
last_log_time = time.time()

# Initialize the camera
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video source.")
else:
    try:
        while True: 
            ret, frame = cap.read()
            if not ret:
                print("Error: Failed to capture frame.")
                break

            image_np = np.array(frame)
            
            input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
            detections = detect_fn(input_tensor)
            
            num_detections = int(detections.pop('num_detections'))
            detections = {key: value[0, :num_detections].numpy()
                          for key, value in detections.items()}
            detections['num_detections'] = num_detections

            # detection_classes should be ints.
            detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

            label_id_offset = 1
            image_np_with_detections = image_np.copy()

            viz_utils.visualize_boxes_and_labels_on_image_array(
                        image_np_with_detections,
                        detections['detection_boxes'],
                        detections['detection_classes'] + label_id_offset,
                        detections['detection_scores'],
                        category_index,
                        use_normalized_coordinates=True,
                        max_boxes_to_draw=5,
                        min_score_thresh=.5,
                        agnostic_mode=False)

            cv2.imshow('object detection', cv2.resize(image_np_with_detections, (800, 600)))

            # Log detected objects with a score of over 80%, but only once every second
            current_time = time.time()
            if current_time - last_log_time >= 1:
                logged_objects = log_detected_objects(detections, category_index)
                detected_objects_log.extend(logged_objects)
                print(f"Logged objects: {logged_objects}")  # Print the logged objects with confidence scores
                last_log_time = current_time
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    finally:
        cap.release()
        cv2.destroyAllWindows()
        # Print the log of detected objects in list format
        detected_objects = [(entry[0], entry[1]) for entry in detected_objects_log]
        print(f"\ndetected_objects_log = {detected_objects}")
# Out:
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: []
# Logged objects: [('als', 0.85594624)]
# Logged objects: []
# Logged objects: [('ueberwiegend', 0.89608455)]
# Logged objects: [('ueberwiegend', 0.8781417)]
# Logged objects: [('ueberwiegend', 0.88255185)]
# Logged objects: []
# Logged objects: [('ueberwiegend', 0.9357139)]
# Logged objects: []
# Logged objects: []
#
# detected_objects_log = [('als', 0.85594624), ('ueberwiegend', 0.89608455), ('ueberwiegend', 0.8781417), ('ueberwiegend', 0.88255185), ('ueberwiegend', 0.9357139)]

# %%
# remove duplicates/ objects appearing multiple times after each other
def remove_consecutive_duplicates(detected_objects):
    return [detected_objects[i] for i in range(len(detected_objects)) if i == 0 or detected_objects[i][0] != detected_objects[i-1][0]]

# Create cleaned_detected_objects_log
cleaned_detected_objects_log = remove_consecutive_duplicates(detected_objects_log)

# Print the cleaned objects
print(f"\ncleaned_detected_objects_log = {cleaned_detected_objects_log}")
# Out:
# cleaned_detected_objects_log = [('als', 0.85594624), ('ueberwiegend', 0.89608455)]
